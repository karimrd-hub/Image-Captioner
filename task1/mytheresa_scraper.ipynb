# %%
# This code scrapes 500 men clothing images in 1024*1024 resolution
import os
import requests
import time
import re

url = "https://api.mytheresa.com/api"

headers = {
    "accept": "*/*",
    "accept-language": "en",
    "content-type": "text/plain;charset=UTF-8",
    "origin": "https://www.mytheresa.com",
    "priority": "u=1, i",
    "referer": "https://www.mytheresa.com/",
    "sec-ch-ua": '"Not;A=Brand";v="99", "Microsoft Edge";v="139", "Chromium";v="139"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-site",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36 Edg/139.0.0.0",
    "x-country": "GB",
    "x-region": "BY",
    "x-section": "men",      # men section
    "x-store": "GB",
}

cookies = {
    "mt_consent": "4",
}

json_query = """query XProductListingPageQuery($categories: [String], $colors: [String], $designers: [String], $fta: Boolean, $materials: [String], $page: Int, $patterns: [String], $reductionRange: [String], $saleStatus: SaleStatusEnum, $size: Int, $sizesHarmonized: [String], $slug: String, $sort: String) {
  xProductListingPage(categories: $categories, colors: $colors, designers: $designers, fta: $fta, materials: $materials, page: $page, patterns: $patterns, reductionRange: $reductionRange, saleStatus: $saleStatus, size: $size, sizesHarmonized: $sizesHarmonized, slug: $slug, sort: $sort) {
    products {
      name
      displayImages
    }
  }
}"""

save_dir = "./men_clothing"
os.makedirs(save_dir, exist_ok=True)

def force_1024_image_url(url):
    # Replace size segments like /1088/1088/ or /720/720/ with /1024/1024/
    return re.sub(r'/\d{3,4}/\d{3,4}/', '/1024/1024/', url)

def download_images_for_page(page, max_images=None):
    variables = {
        "categories": [],
        "colors": [],
        "designers": [],
        "fta": None,
        "materials": [],
        "page": page,
        "patterns": [],
        "reductionRange": [],
        "saleStatus": None,
        "size": 60,
        "sizesHarmonized": [],
        "slug": "/clothing",
        "sort": None,
    }

    json_data = {
        "query": json_query,
        "variables": variables,
    }

    print(f"Requesting page {page} ...")
    response = requests.post(url, headers=headers, cookies=cookies, json=json_data)
    if response.status_code != 200:
        print(f"Failed to fetch page {page}: status {response.status_code}")
        return

    data = response.json()
    products = data.get('data', {}).get('xProductListingPage', {}).get('products', [])
    print(f"Found {len(products)} products on page {page}")

    count = 0
    for idx, product in enumerate(products, start=1):
        if max_images and count >= max_images:
            break
        images = product.get('displayImages', [])
        if not images:
            continue
        img_url = force_1024_image_url(images[0])  # enforce 1024x1024

        try:
            img_response = requests.get(img_url)
            img_response.raise_for_status()
            ext = img_url.split('.')[-1].split('?')[0]
            safe_name = product.get('name', 'product').replace(' ', '_').replace('/', '_')
            filename = f"page{page}_{safe_name}_{idx}.{ext}"
            filepath = os.path.join(save_dir, filename)
            with open(filepath, 'wb') as f:
                f.write(img_response.content)
            print(f"Saved image: {filepath}")
            count += 1
            time.sleep(0.1)
        except Exception as e:
            print(f"Failed to download image {img_url}: {e}")

# Download full pages 1 to 8
for page_num in range(1, 9):
    download_images_for_page(page_num)

# Download only 20 images from page 9
download_images_for_page(9, max_images=20)
# Out:
# Requesting page 1 ...
# Found 60 products on page 1
# Saved image: ./task1/men_clothing\page1_Edrice_leather_jacket_1.jpg
# Saved image: ./task1/men_clothing\page1_Thane_cotton_poplin_shirt_2.jpg
# Saved image: ./task1/men_clothing\page1_Mid-rise_straight_jeans_3.jpg
# Saved image: ./task1/men_clothing\page1_Striped_cotton_hoodie_4.jpg
# Saved image: ./task1/men_clothing\page1_Traveller_suede_jacket_5.jpg
# Saved image: ./task1/men_clothing\page1_Logo_wool_and_cotton_sweater_6.jpg
# Saved image: ./task1/men_clothing\page1_Straight_jeans_7.jpg
# Saved image: ./task1/men_clothing\page1_Cotton_field_jacket_8.jpg
# Saved image: ./task1/men_clothing\page1_Sequined_cotton_bouclé_blazer_9.jpg
# Saved image: ./task1/men_clothing\page1_Sequined_cotton_bouclé_straight_pants_10.jpg
# Saved image: ./task1/men_clothing\page1_Cotton_poplin_shirt_11.jpg
# Saved image: ./task1/men_clothing\page1_Virgin_wool_suit_12.jpg
# Saved image: ./task1/men_clothing\page1_Printed_silk_bowling_shirt_13.jpg
# Saved image: ./task1/men_clothing\page1_Wool_gabardine_straight_pants_14.jpg
# Saved image: ./task1/men_clothing\page1_Mid-rise_barrel-leg_jeans_15.jpg
# Saved image: ./task1/men_clothing\page1_Floral_reversible_jacket_16.jpg
# Saved image: ./task1/men_clothing\page1_Leather_bomber_jacket_17.jpg
# Saved image: ./task1/men_clothing\page1_Striped_cotton_bowling_shirt_18.jpg
# Saved image: ./task1/men_clothing\page1_Xon_virgin_wool_straight_pants_19.jpg
# Saved image: ./task1/men_clothing\page1_Checked_fringed_virgin_wool_jacket_20.jpg
# Saved image: ./task1/men_clothing\page1_Cotton_and_linen_canvas_shirt_21.jpg
# Saved image: ./task1/men_clothing\page1_Mid-rise_wide-leg_jeans_22.jpg
# Saved image: ./task1/men_clothing\page1_Morton_straight_jeans_23.jpg
# Saved image: ./task1/men_clothing\page1_Double_G_checked_wool-blend_overshirt_24.jpg
# Saved image: ./task1/men_clothing\page1_Tweed_bomber_jacket_25.jpg
# Saved image: ./task1/men_clothing\page1_Vasil_high-rise_straight_jeans_26.jpg
# Saved image: ./task1/men_clothing\page1_Low-rise_flared_jeans_27.jpg
# Saved image: ./task1/men_clothing\page1_Leather_bomber_jacket_28.jpg
# Saved image: ./task1/men_clothing\page1_Toute_La_V_virgin_wool_jacquard_cardigan_29.jpg
# Saved image: ./task1/men_clothing\page1_Zev_virgin_wool_straight_pants_30.jpg
# Saved image: ./task1/men_clothing\page1_Slim_jeans_31.jpg
# Saved image: ./task1/men_clothing\page1_Wool_jacket_32.jpg
# Saved image: ./task1/men_clothing\page1_Silk-trimmed_wool_and_mohair_blazer_33.jpg
# Saved image: ./task1/men_clothing\page1_Silk-trimmed_wool_and_mohair_slim_pants_34.jpg
# Saved image: ./task1/men_clothing\page1_Cotton-blend_slim_pants__35.jpg
# Saved image: ./task1/men_clothing\page1_Double-breasted_virgin_wool_jacket_36.jpg
# Saved image: ./task1/men_clothing\page1_Joret_corduroy-trimmed_denim_jacket_37.jpg
# Saved image: ./task1/men_clothing\page1_Mid-rise_straight_jeans_38.jpg
# Saved image: ./task1/men_clothing\page1_Anagram_denim_shorts_39.jpg
# Saved image: ./task1/men_clothing\page1_Anagram_denim_bowling_shirt_40.jpg
# Saved image: ./task1/men_clothing\page1_Givenchy_Paris_satin_blouson_41.jpg
# Saved image: ./task1/men_clothing\page1_Trompe_L'Oeil_denim_sweatpants_42.jpg
# Saved image: ./task1/men_clothing\page1_Mid-rise_straight_jeans_43.jpg
# Saved image: ./task1/men_clothing\page1_Intrecciato_cashmere-blend_sweater_44.jpg
# Saved image: ./task1/men_clothing\page1_Floral_intarsia_alpaca_and_wool-blend_sweater__45.jpg
# Saved image: ./task1/men_clothing\page1_Cotton-blend_sweatpants_46.jpg
# Saved image: ./task1/men_clothing\page1_Mid-rise_straight_jeans_47.jpg
# Saved image: ./task1/men_clothing\page1_Knitted_striped_cotton_polo_sweater_48.jpg
# Saved image: ./task1/men_clothing\page1_Striped_cotton_and_silk_bowling_shirt_49.jpg
# Saved image: ./task1/men_clothing\page1_GG_cotton_jacquard_shorts_50.jpg
# Saved image: ./task1/men_clothing\page1_Printed_silk_twill_shorts_51.jpg
# Saved image: ./task1/men_clothing\page1_Printed_silk_twill_bowling_shirt_52.jpg
# Saved image: ./task1/men_clothing\page1_Double-breasted_cotton-blend_velvet_blazer_53.jpg
# Saved image: ./task1/men_clothing\page1_William_striped_cotton_shirt_54.jpg
# Saved image: ./task1/men_clothing\page1_Cotton_straight_pants_55.jpg
# Saved image: ./task1/men_clothing\page1_Wool_and_suede_blouson_56.jpg
# Saved image: ./task1/men_clothing\page1_Wool_blazer_57.jpg
# Saved image: ./task1/men_clothing\page1_Cotton_poplin_bowling_shirt_58.jpg
# Saved image: ./task1/men_clothing\page1_Mid-rise_straight_jeans_59.jpg
# Saved image: ./task1/men_clothing\page1_Wool_and_cashmere_jacket_60.jpg
# Requesting page 2 ...
# Found 60 products on page 2
# Saved image: ./task1/men_clothing\page2_Houndstooth_blouson_1.jpg
# Saved image: ./task1/men_clothing\page2_Mick_straight_jeans_2.jpg
# Saved image: ./task1/men_clothing\page2_Twill_straight_pants_3.jpg
# Saved image: ./task1/men_clothing\page2_Colorblocked_logo_zip-up_sweatshirt_4.jpg
# Saved image: ./task1/men_clothing\page2_Bulles_Royales_cotton_poplin_bowling_shirt_5.jpg
# Saved image: ./task1/men_clothing\page2_Printed_cotton_poplin_shorts_6.jpg
# Saved image: ./task1/men_clothing\page2_Cotton-blend_Bermuda_shorts_7.jpg
# Saved image: ./task1/men_clothing\page2_Printed_silk_bowling_shirt_8.jpg
# Saved image: ./task1/men_clothing\page2_Givenchy_Stamp_technical_jacket_9.jpg
# Saved image: ./task1/men_clothing\page2_Givenchy_Paris_cotton_bowling_shirt_10.jpg
# Saved image: ./task1/men_clothing\page2_Givenchy_Stamp_cotton_fleece_sweatpants_11.jpg
# Saved image: ./task1/men_clothing\page2_Suede_down_vest__12.jpg
# Saved image: ./task1/men_clothing\page2_Jacquard_terry_bowling_shirt_13.jpg
# Saved image: ./task1/men_clothing\page2_Printed_cotton-blend_terry_Bermuda_shorts_14.jpg
# Saved image: ./task1/men_clothing\page2_Faded_slim_jeans_15.jpg
# Saved image: ./task1/men_clothing\page2_Horsebit_silk_twill_bowling_shirt_16.jpg
# Saved image: ./task1/men_clothing\page2_Zigzag_cotton_polo_sweater_17.jpg
# Saved image: ./task1/men_clothing\page2_Roma_paisley_slim_jeans_18.jpg
# Saved image: ./task1/men_clothing\page2_Faded_mid-rise_straight_jeans_19.jpg
# Saved image: ./task1/men_clothing\page2_Givenchy_Stamp_cotton-blend_bomber_jacket_20.jpg
# Saved image: ./task1/men_clothing\page2_Anagram_wool_sweater_21.jpg
# Saved image: ./task1/men_clothing\page2_Jacquard-trimmed_wide-leg_jeans_22.jpg
# Saved image: ./task1/men_clothing\page2_Twill_straight_pants_23.jpg
# Saved image: ./task1/men_clothing\page2_Logo_cotton-blend_zip-up_cardigan__24.jpg
# Saved image: ./task1/men_clothing\page2_Sicilia_linen_blazer_25.jpg
# Saved image: ./task1/men_clothing\page2_Linen_straight_pants__26.jpg
# Saved image: ./task1/men_clothing\page2_Silk_tapered_pants__27.jpg
# Saved image: ./task1/men_clothing\page2_Sicilia_Light_silk_twill_blazer_28.jpg
# Saved image: ./task1/men_clothing\page2_Printed_silk_crêpe_shirt_29.jpg
# Saved image: ./task1/men_clothing\page2_Linen_straight_pants_30.jpg
# Saved image: ./task1/men_clothing\page2_Cotton_corduroy_chinos_31.jpg
# Saved image: ./task1/men_clothing\page2_Leather_blouson_32.jpg
# Saved image: ./task1/men_clothing\page2_Anagram_wide-leg_jeans_33.jpg
# Saved image: ./task1/men_clothing\page2_Mid-rise_slim_jeans_34.jpg
# Saved image: ./task1/men_clothing\page2_GG_Canvas_cotton-blend_jacket_35.jpg
# Saved image: ./task1/men_clothing\page2_Logo_virgin_wool_varsity_jacket_36.jpg
# Saved image: ./task1/men_clothing\page2_Mick_mid-rise_straight_jeans_37.jpg
# Saved image: ./task1/men_clothing\page2_Cotton_corduroy_slim_pants_38.jpg
# Saved image: ./task1/men_clothing\page2_Suede_jacket_39.jpg
# Saved image: ./task1/men_clothing\page2_Linen_blazer_40.jpg
# Saved image: ./task1/men_clothing\page2_Amo_linen_suit_pants_41.jpg
# Saved image: ./task1/men_clothing\page2_Cotton_straight_pants_42.jpg
# Saved image: ./task1/men_clothing\page2_Cotton,_linen,_and_silk_jacket_43.jpg
# Saved image: ./task1/men_clothing\page2_Checked_technical_jacket_44.jpg
# Saved image: ./task1/men_clothing\page2_Ross_straight_jeans_45.jpg
# Saved image: ./task1/men_clothing\page2_Virgin_wool_straight_pants_46.jpg
# Saved image: ./task1/men_clothing\page2_Silk-blend_polo_shirt_47.jpg
# Saved image: ./task1/men_clothing\page2_Paisley_linen_bowling_shirt_48.jpg
# Saved image: ./task1/men_clothing\page2_Paisley_swim_trunks_49.jpg
# Saved image: ./task1/men_clothing\page2_Explorer_cashmere_and_cotton_denim_shorts_50.jpg
# Saved image: ./task1/men_clothing\page2_Explorer_cashmere_and_cotton_denim_jacket_51.jpg
# Saved image: ./task1/men_clothing\page2_Adorn_printed_cotton_and_silk_shirt_52.jpg
# Saved image: ./task1/men_clothing\page2_Vast_Cut_embroidered_straight_jeans_53.jpg
# Saved image: ./task1/men_clothing\page2_Striped_mid-rise_pajama_pants_54.jpg
# Saved image: ./task1/men_clothing\page2_Beyond_cotton_and_silk_bowling_shirt_55.jpg
# Saved image: ./task1/men_clothing\page2_Suede_jacket_56.jpg
# Saved image: ./task1/men_clothing\page2_Straight_jeans_57.jpg
# Saved image: ./task1/men_clothing\page2_Cotton_twill_chinos_58.jpg
# Saved image: ./task1/men_clothing\page2_Roma_printed_wool-blend_blazer_59.jpg
# Saved image: ./task1/men_clothing\page2_Set_of_3_logo_cotton_jersey_T-shirts_60.jpg
# Requesting page 3 ...
# Found 60 products on page 3
# Saved image: ./task1/men_clothing\page3_Set_of_3_cotton_jersey_T-shirts_1.jpg
# Saved image: ./task1/men_clothing\page3_Set_of_2_cotton-blend_briefs_2.jpg
# Saved image: ./task1/men_clothing\page3_Set_of_2_logo_cotton-blend_boxer_briefs_3.jpg
# Saved image: ./task1/men_clothing\page3_Cotton-blend_jersey_T-shirt_4.jpg
# Saved image: ./task1/men_clothing\page3_Maya_down_jacket_5.jpg
# Saved image: ./task1/men_clothing\page3_Set_of_3_cotton_jersey_T-shirts_6.jpg
# Saved image: ./task1/men_clothing\page3_Logo_cotton_T-shirt_7.jpg
# Saved image: ./task1/men_clothing\page3_Anagram_cotton_T-shirt_8.jpg
# Saved image: ./task1/men_clothing\page3_Cotton_jersey_T-shirt_9.jpg
# Saved image: ./task1/men_clothing\page3_Cotton-blend_velvet_polo_shirt_10.jpg
# Saved image: ./task1/men_clothing\page3_Striped_cotton_polo_sweater_11.jpg
# Saved image: ./task1/men_clothing\page3_Cotton-blend_sweater_12.jpg
# Saved image: ./task1/men_clothing\page3_Cotton_polo_shirt_13.jpg
# Saved image: ./task1/men_clothing\page3_Cotton_sweatshirt_14.jpg
# Saved image: ./task1/men_clothing\page3_Anagram_cotton_poplin_shirt_15.jpg
# Saved image: ./task1/men_clothing\page3_Tripiti_down_jacket_16.jpg
# Saved image: ./task1/men_clothing\page3_GG_cotton_piqué_jacquard_polo_shirt_17.jpg
# Saved image: ./task1/men_clothing\page3_Cotton_polo_shirt_18.jpg
# Saved image: ./task1/men_clothing\page3_Franz_cashmere_polo_sweater_19.jpg
# Saved image: ./task1/men_clothing\page3_Wool-blend_sweater_20.jpg
# Saved image: ./task1/men_clothing\page3_Compa_virgin_wool_coat_21.jpg
# Saved image: ./task1/men_clothing\page3_Leather_bomber_jacket_22.jpg
# Saved image: ./task1/men_clothing\page3_Cashmere_and_wool_sweater_23.jpg
# Saved image: ./task1/men_clothing\page3_Rod_cashmere_sweater_24.jpg
# Saved image: ./task1/men_clothing\page3_Franz_cashmere_polo_sweater_25.jpg
# Saved image: ./task1/men_clothing\page3_Wool_straight_pants_26.jpg
# Saved image: ./task1/men_clothing\page3_Cotton_gabardine_overshirt_27.jpg
# Saved image: ./task1/men_clothing\page3_Carlo_cotton-blend_chinos_28.jpg
# Saved image: ./task1/men_clothing\page3_Silk-blend_shirt_29.jpg
# Saved image: ./task1/men_clothing\page3_Printed_cotton_jersey_T-shirt_30.jpg
# Saved image: ./task1/men_clothing\page3_Luserna_down_jacket_31.jpg
# Saved image: ./task1/men_clothing\page3_Brieuc_down_jacket_32.jpg
# Saved image: ./task1/men_clothing\page3_Mouliné_wool_and_cashmere_sweater_33.jpg
# Saved image: ./task1/men_clothing\page3_Striped_cotton_shirt_34.jpg
# Saved image: ./task1/men_clothing\page3_Herringbone_wool-blend_wide-leg_pants_35.jpg
# Saved image: ./task1/men_clothing\page3_Logo_cotton_jersey_T-shirt_36.jpg
# Saved image: ./task1/men_clothing\page3_Cotton_piqué_shirt_37.jpg
# Saved image: ./task1/men_clothing\page3_Striped_cotton_poplin_shirt_38.jpg
# Saved image: ./task1/men_clothing\page3_Cotton_poplin_shirt_39.jpg
# Saved image: ./task1/men_clothing\page3_Poplin_shirt_40.jpg
# Saved image: ./task1/men_clothing\page3_Wool_and_silk_sweater_41.jpg
# Saved image: ./task1/men_clothing\page3_Ferro_wool-blend_coat_42.jpg
# Saved image: ./task1/men_clothing\page3_Anagram_cotton_poplin_bowling_shirt_43.jpg
# Saved image: ./task1/men_clothing\page3_Cotton-blend_terry_polo_shirt_44.jpg
# Saved image: ./task1/men_clothing\page3_Mid-rise_bootcut_jeans_45.jpg
# Saved image: ./task1/men_clothing\page3_Couyere_hooded_down_jacket_46.jpg
# Saved image: ./task1/men_clothing\page3_Cotton_jersey_T-shirt_47.jpg
# Saved image: ./task1/men_clothing\page3_Wool-blend_shorts_48.jpg
# Saved image: ./task1/men_clothing\page3_Wool_and_silk_half-zip_sweater_49.jpg
# Saved image: ./task1/men_clothing\page3_Horik_cashmere_sweater_50.jpg
# Saved image: ./task1/men_clothing\page3_Paneled_suede_and_wool_jacket_51.jpg
# Saved image: ./task1/men_clothing\page3_Cotton-blend_sweatshirt_52.jpg
# Saved image: ./task1/men_clothing\page3_Wool_suit_53.jpg
# Saved image: ./task1/men_clothing\page3_Anagram_cotton_twill_shorts_54.jpg
# Saved image: ./task1/men_clothing\page3_Wool_suit_55.jpg
# Saved image: ./task1/men_clothing\page3_Cotton-blend_Henley_shirt_56.jpg
# Saved image: ./task1/men_clothing\page3_Wool_blazer_57.jpg
# Saved image: ./task1/men_clothing\page3_Cotton_jersey_T-shirt__58.jpg
# Saved image: ./task1/men_clothing\page3_Paneled_suede_and_wool_jacket_59.jpg
# Saved image: ./task1/men_clothing\page3_Cernay_suede_down_jacket_60.jpg
# Requesting page 4 ...
# Found 60 products on page 4
# Saved image: ./task1/men_clothing\page4_Avoine_quilted_down_jacket_1.jpg
# Saved image: ./task1/men_clothing\page4_Hooded_cotton_twill_jacket_2.jpg
# Saved image: ./task1/men_clothing\page4_Shearling-trimmed_leather_bomber_jacket_3.jpg
# Saved image: ./task1/men_clothing\page4_Paneled_down_jacket_4.jpg
# Saved image: ./task1/men_clothing\page4_Danube_cashmere_and_silk_cardigan_5.jpg
# Saved image: ./task1/men_clothing\page4_Silk_T-shirt_6.jpg
# Saved image: ./task1/men_clothing\page4_Technical_straight_pants_7.jpg
# Saved image: ./task1/men_clothing\page4_Wool-blend_jacket_8.jpg
# Saved image: ./task1/men_clothing\page4_Couyere_hooded_down_jacket_9.jpg
# Saved image: ./task1/men_clothing\page4_Anagram_checked_shirt_10.jpg
# Saved image: ./task1/men_clothing\page4_Cotton-blend_slim_pants_11.jpg
# Saved image: ./task1/men_clothing\page4_Toute_La_V_virgin_wool_jacquard_sweater_12.jpg
# Saved image: ./task1/men_clothing\page4_Pinstripe_wool_blazer_13.jpg
# Saved image: ./task1/men_clothing\page4_Mid-rise_slim_jeans_14.jpg
# Saved image: ./task1/men_clothing\page4_Cernay_suede_down_jacket_15.jpg
# Saved image: ./task1/men_clothing\page4_Down-paneled_wool_and_cashmere_jacket_16.jpg
# Saved image: ./task1/men_clothing\page4_Ambroisie_cotton_corduroy_down_jacket_17.jpg
# Saved image: ./task1/men_clothing\page4_Checked_overshirt_18.jpg
# Saved image: ./task1/men_clothing\page4_Shearling-trimmed_virgin_wool_blouson_19.jpg
# Saved image: ./task1/men_clothing\page4_Anagram_jersey_track_jacket_20.jpg
# Saved image: ./task1/men_clothing\page4_DG_embroidered_cotton_piqué_polo_shirt_21.jpg
# Saved image: ./task1/men_clothing\page4_Cotton-blend_shirt_22.jpg
# Saved image: ./task1/men_clothing\page4_Lamé_jacquard_sweater_23.jpg
# Saved image: ./task1/men_clothing\page4_Maya_down_jacket_24.jpg
# Saved image: ./task1/men_clothing\page4_Layered_striped_cotton_polo_shirt_25.jpg
# Saved image: ./task1/men_clothing\page4_Wool_blazer_26.jpg
# Saved image: ./task1/men_clothing\page4_Cotton_shirt_27.jpg
# Saved image: ./task1/men_clothing\page4_Cotton-blend_cargo_pants_28.jpg
# Saved image: ./task1/men_clothing\page4_Givenchy_Paris_cotton_poplin_shirt_29.jpg
# Saved image: ./task1/men_clothing\page4_Striped_cotton_polo_sweater_30.jpg
# Saved image: ./task1/men_clothing\page4_Logo_cotton_blouson_31.jpg
# Saved image: ./task1/men_clothing\page4_Cotton_jersey_polo_shirt__32.jpg
# Saved image: ./task1/men_clothing\page4_Ribbed-knit_cotton-blend_Henley_shirt_33.jpg
# Saved image: ./task1/men_clothing\page4_Virgin_wool_straight_pants_34.jpg
# Saved image: ./task1/men_clothing\page4_Anagram_cotton_jersey_T-shirt_35.jpg
# Saved image: ./task1/men_clothing\page4_Re-Nylon_padded_jacket_36.jpg
# Saved image: ./task1/men_clothing\page4_Studded_leather_jacket_37.jpg
# Saved image: ./task1/men_clothing\page4_Logo_polka-dot_silk-blend_shorts_38.jpg
# Saved image: ./task1/men_clothing\page4_Givenchy_Stamp_cotton_fleece_hoodie_39.jpg
# Saved image: ./task1/men_clothing\page4_Anagram_cotton_jersey_T-shirt__40.jpg
# Saved image: ./task1/men_clothing\page4_Cotton_corduroy_slim_pants_41.jpg
# Saved image: ./task1/men_clothing\page4_Pinstripe_wool_straight_pants_42.jpg
# Saved image: ./task1/men_clothing\page4_Jersey_track_jacket_43.jpg
# Saved image: ./task1/men_clothing\page4_Logo_cotton_jersey_T-shirt__44.jpg
# Saved image: ./task1/men_clothing\page4_Cotton_piqué_polo_45.jpg
# Saved image: ./task1/men_clothing\page4_Cable-knit_cashmere_cardigan_46.jpg
# Saved image: ./task1/men_clothing\page4_Mid-rise_straight_jeans_47.jpg
# Saved image: ./task1/men_clothing\page4_Fringed_suede_jacket_48.jpg
# Saved image: ./task1/men_clothing\page4_Cotton_hoodie_49.jpg
# Saved image: ./task1/men_clothing\page4_Jersey_T-shirt_50.jpg
# Saved image: ./task1/men_clothing\page4_Cotton_polo_shirt_51.jpg
# Saved image: ./task1/men_clothing\page4_Cotton_straight_pants_52.jpg
# Saved image: ./task1/men_clothing\page4_Logo_cotton-blend_boxer_briefs_53.jpg
# Saved image: ./task1/men_clothing\page4_Givenchy_Stamp_cotton_Bermuda_shorts_54.jpg
# Saved image: ./task1/men_clothing\page4_Gio_silk_sweater_55.jpg
# Saved image: ./task1/men_clothing\page4_Teddy_jacket_56.jpg
# Saved image: ./task1/men_clothing\page4_Cotton_crewneck_sweater_57.jpg
# Saved image: ./task1/men_clothing\page4_Cotton_jersey_T-shirt_58.jpg
# Saved image: ./task1/men_clothing\page4_Ray_cotton_jersey_T-shirt_59.jpg
# Saved image: ./task1/men_clothing\page4_Kemet_cotton_parka_60.jpg
# Requesting page 5 ...
# Found 60 products on page 5
# Saved image: ./task1/men_clothing\page5_Gio_silk_sweater_1.jpg
# Saved image: ./task1/men_clothing\page5_Moncler_Maya_down_jacket_2.jpg
# Saved image: ./task1/men_clothing\page5_Virolais_down_jacket_3.jpg
# Saved image: ./task1/men_clothing\page5_Cotton-blend_velour_track_jacket_4.jpg
# Saved image: ./task1/men_clothing\page5_Cotton_voile_shirt_5.jpg
# Saved image: ./task1/men_clothing\page5_Cotton_corduroy_pants_6.jpg
# Saved image: ./task1/men_clothing\page5_Wool_cardigan_7.jpg
# Saved image: ./task1/men_clothing\page5_Cotton-blend_shirt_8.jpg
# Saved image: ./task1/men_clothing\page5_Logo_cotton_jersey_T-shirt_9.jpg
# Saved image: ./task1/men_clothing\page5_Wool_shirt_10.jpg
# Saved image: ./task1/men_clothing\page5_Givenchy_Stamp_cotton-blend_raincoat_11.jpg
# Saved image: ./task1/men_clothing\page5_Cotton_piqué_polo_shirt_12.jpg
# Saved image: ./task1/men_clothing\page5_Double_G_cotton-blend_piqué_polo_shirt_13.jpg
# Saved image: ./task1/men_clothing\page5_Printed_swim_trunks_14.jpg
# Saved image: ./task1/men_clothing\page5_Cotton_shirt_15.jpg
# Saved image: ./task1/men_clothing\page5_Mid-rise_straight_jeans_16.jpg
# Saved image: ./task1/men_clothing\page5_Piqué_polo_shirt_17.jpg
# Saved image: ./task1/men_clothing\page5_Virgin_wool_coat_18.jpg
# Saved image: ./task1/men_clothing\page5_Cassandre_silk_crêpe_de_chine_shirt_19.jpg
# Saved image: ./task1/men_clothing\page5_Cotton_piqué_polo_shirt_20.jpg
# Saved image: ./task1/men_clothing\page5_Striped_wool_sweater_21.jpg
# Saved image: ./task1/men_clothing\page5_Technical_jersey_zip-up_sweatshirt_22.jpg
# Saved image: ./task1/men_clothing\page5_Cotton_shirt_23.jpg
# Saved image: ./task1/men_clothing\page5_Checked_cotton-blend_shirt_24.jpg
# Saved image: ./task1/men_clothing\page5_Wool_zip-up_sweater_25.jpg
# Saved image: ./task1/men_clothing\page5_Checked_cotton_shirt_26.jpg
# Saved image: ./task1/men_clothing\page5_Cotton_corduroy_overshirt_27.jpg
# Saved image: ./task1/men_clothing\page5_Intrecciato_wool_blouson_28.jpg
# Saved image: ./task1/men_clothing\page5_Intreccio_wool-blend_sweater_29.jpg
# Saved image: ./task1/men_clothing\page5_Cotton_polo_shirt_30.jpg
# Saved image: ./task1/men_clothing\page5_Linen_shirt_31.jpg
# Saved image: ./task1/men_clothing\page5_Logo_swim_trunks_32.jpg
# Saved image: ./task1/men_clothing\page5_Maya_down_jacket_33.jpg
# Saved image: ./task1/men_clothing\page5_Zindel_striped_cotton_shorts_34.jpg
# Saved image: ./task1/men_clothing\page5_Intrecciato_cotton_jersey_polo_sweater_35.jpg
# Saved image: ./task1/men_clothing\page5_Carlo_wool_and_cashmere_straight_pants_36.jpg
# Saved image: ./task1/men_clothing\page5_Silk_slim_pants_37.jpg
# Saved image: ./task1/men_clothing\page5_Twill_shirt_38.jpg
# Saved image: ./task1/men_clothing\page5_Cotton_corduroy_wide-leg_pants_39.jpg
# Saved image: ./task1/men_clothing\page5_Wool_cardigan_40.jpg
# Saved image: ./task1/men_clothing\page5_Cotton_jersey_T-shirt_41.jpg
# Saved image: ./task1/men_clothing\page5_Treccia_cable-knit_cashmere_socks_42.jpg
# Saved image: ./task1/men_clothing\page5_Bry_cotton_polo_shirt_43.jpg
# Saved image: ./task1/men_clothing\page5_Cotton_poplin_shirt_44.jpg
# Saved image: ./task1/men_clothing\page5_Twill_shirt_45.jpg
# Saved image: ./task1/men_clothing\page5_Checked_wool_overshirt_46.jpg
# Saved image: ./task1/men_clothing\page5_Logo_cotton_jersey_T-shirt_47.jpg
# Saved image: ./task1/men_clothing\page5_Sciros_hooded_down_jacket_48.jpg
# Saved image: ./task1/men_clothing\page5_Matt_cotton_corduroy_shirt__49.jpg
# Saved image: ./task1/men_clothing\page5_Re-Nylon_blouson_50.jpg
# Saved image: ./task1/men_clothing\page5_Cotton_piqué_polo_shirt_51.jpg
# Saved image: ./task1/men_clothing\page5_Jersey_track_pants_52.jpg
# Saved image: ./task1/men_clothing\page5_Checked_cotton_poplin_shirt_53.jpg
# Saved image: ./task1/men_clothing\page5_Houndstooth_double-breasted_wool_overcoat_54.jpg
# Saved image: ./task1/men_clothing\page5_Loop_Sports_Icon_track_jacket_55.jpg
# Saved image: ./task1/men_clothing\page5_Fred_straight_jeans_56.jpg
# Saved image: ./task1/men_clothing\page5_Tibb_down_vest_57.jpg
# Saved image: ./task1/men_clothing\page5_Wool_suit_jacket_58.jpg
# Saved image: ./task1/men_clothing\page5_Jersey_T-shirt_59.jpg
# Saved image: ./task1/men_clothing\page5_Jarno_cotton-blend_Bermuda_shorts_60.jpg
# Requesting page 6 ...
# Found 60 products on page 6
# Saved image: ./task1/men_clothing\page6_LS_cotton_shirt__1.jpg
# Saved image: ./task1/men_clothing\page6_Whitney_cotton-blend_jersey_bomber_jacket_2.jpg
# Saved image: ./task1/men_clothing\page6_Intreccio_leather_jacket_3.jpg
# Saved image: ./task1/men_clothing\page6_Jacquard_logo_cotton_bowling_shirt_4.jpg
# Saved image: ./task1/men_clothing\page6_Logo_cotton_jersey_T-shirt_5.jpg
# Saved image: ./task1/men_clothing\page6_Carlo_cotton-blend_chinos_6.jpg
# Saved image: ./task1/men_clothing\page6_Reversible_vest_7.jpg
# Saved image: ./task1/men_clothing\page6_Valerio_cotton_straight_pants_8.jpg
# Saved image: ./task1/men_clothing\page6_Cashmere_and_silk_polo_sweater_9.jpg
# Saved image: ./task1/men_clothing\page6_Wool_sweater_10.jpg
# Saved image: ./task1/men_clothing\page6_Leather_bomber_jacket__11.jpg
# Saved image: ./task1/men_clothing\page6_Simorre_cotton-blend_jersey_jacket_12.jpg
# Saved image: ./task1/men_clothing\page6_Logo_embroidered_cotton_piqué_polo_shirt_13.jpg
# Saved image: ./task1/men_clothing\page6_Cotton_straight_pants_14.jpg
# Saved image: ./task1/men_clothing\page6_Cotton_shirt_15.jpg
# Saved image: ./task1/men_clothing\page6_Wool_turtleneck_sweater_16.jpg
# Saved image: ./task1/men_clothing\page6_Wool_and_silk_polo_shirt_17.jpg
# Saved image: ./task1/men_clothing\page6_Shearling-trimmed_suede_blouson_18.jpg
# Saved image: ./task1/men_clothing\page6_Cotton_twill_shirt_19.jpg
# Saved image: ./task1/men_clothing\page6_Traveller_field_jacket_20.jpg
# Saved image: ./task1/men_clothing\page6_Lipsi_logo_down_vest_21.jpg
# Saved image: ./task1/men_clothing\page6_Cotton_denim_jacket_22.jpg
# Saved image: ./task1/men_clothing\page6_Majolica_printed_cotton_shirt_23.jpg
# Saved image: ./task1/men_clothing\page6_Cotton_piqué_polo_shirt_24.jpg
# Saved image: ./task1/men_clothing\page6_Carlo_wool_and_cashmere_straight_pants_25.jpg
# Saved image: ./task1/men_clothing\page6_Cotton_piqué_polo_shirt_26.jpg
# Saved image: ./task1/men_clothing\page6_GG_Canvas_cotton-blend_shirt_27.jpg
# Saved image: ./task1/men_clothing\page6_Logo_silk_and_cotton_polo_shirt_28.jpg
# Saved image: ./task1/men_clothing\page6_Jersey_T-shirt_29.jpg
# Saved image: ./task1/men_clothing\page6_Cable-knit_cotton_cardigan_30.jpg
# Saved image: ./task1/men_clothing\page6_Jarno_cotton-blend_Bermuda_shorts_31.jpg
# Saved image: ./task1/men_clothing\page6_Cotton-blend_slim_pants_32.jpg
# Saved image: ./task1/men_clothing\page6_Windmate®_suede-trimmed_coat_33.jpg
# Saved image: ./task1/men_clothing\page6_GG_Canvas_bomber_jacket_34.jpg
# Saved image: ./task1/men_clothing\page6_Wool_polo_shirt_35.jpg
# Saved image: ./task1/men_clothing\page6_Wool_socks_36.jpg
# Saved image: ./task1/men_clothing\page6_Wool_and_cashmere_sweater_37.jpg
# Saved image: ./task1/men_clothing\page6_Cashmere_and_silk_polo_sweater_38.jpg
# Saved image: ./task1/men_clothing\page6_Cotton_jersey_wide-leg_sweatpants_39.jpg
# Saved image: ./task1/men_clothing\page6_Anagram_cotton_poplin_shirt_40.jpg
# Saved image: ./task1/men_clothing\page6_Ribbed-knit_wool_and_cashmere_sweater_41.jpg
# Saved image: ./task1/men_clothing\page6_Logo_cotton_poplin_shirt_42.jpg
# Saved image: ./task1/men_clothing\page6_Windwish_Storm_quilted_vest_43.jpg
# Saved image: ./task1/men_clothing\page6_Cable-knit_cashmere_zip-up_sweater_44.jpg
# Saved image: ./task1/men_clothing\page6_Twill_bomber_jacket_45.jpg
# Saved image: ./task1/men_clothing\page6_Polka-dot_printed_shirt_46.jpg
# Saved image: ./task1/men_clothing\page6_Prince_of_Wales_check_cotton_shirt_47.jpg
# Saved image: ./task1/men_clothing\page6_Levitha_down_jacket_48.jpg
# Saved image: ./task1/men_clothing\page6_Suede_jacket_49.jpg
# Saved image: ./task1/men_clothing\page6_Cotton_sweater_50.jpg
# Saved image: ./task1/men_clothing\page6_Wool_and_cashmere_cardigan_51.jpg
# Saved image: ./task1/men_clothing\page6_Logo_oversized_cotton_jersey_T-shirt__52.jpg
# Saved image: ./task1/men_clothing\page6_Piqué_polo_shirt_53.jpg
# Saved image: ./task1/men_clothing\page6_Floral_cotton_bowling_shirt_54.jpg
# Saved image: ./task1/men_clothing\page6_Striped_cotton_jersey_polo_shirt_55.jpg
# Saved image: ./task1/men_clothing\page6_Padded_down_jacket_56.jpg
# Saved image: ./task1/men_clothing\page6_Cotton-blend_tapered_pants_57.jpg
# Saved image: ./task1/men_clothing\page6_Cotton_polo_shirt_58.jpg
# Saved image: ./task1/men_clothing\page6_GG_cotton-blend_Bermuda_shorts_59.jpg
# Saved image: ./task1/men_clothing\page6_Cotton_polo_shirt_60.jpg
# Requesting page 7 ...
# Found 60 products on page 7
# Saved image: ./task1/men_clothing\page7_Quilted_cotton-blend_overshirt__1.jpg
# Saved image: ./task1/men_clothing\page7_Treompan_down_vest_2.jpg
# Saved image: ./task1/men_clothing\page7_DG_cotton_and_silk_piqué_bowling_shirt_3.jpg
# Saved image: ./task1/men_clothing\page7_GG_cotton_shirt_4.jpg
# Saved image: ./task1/men_clothing\page7_Cotton-blend_zip-up_sweatshirt_5.jpg
# Saved image: ./task1/men_clothing\page7_Logo_silk_and_cotton_T-shirt_6.jpg
# Saved image: ./task1/men_clothing\page7_Jonage_hooded_down_jacket_7.jpg
# Saved image: ./task1/men_clothing\page7_Cashmere-blend_cardigan_8.jpg
# Saved image: ./task1/men_clothing\page7_Mid-rise_cotton_Bermuda_shorts_9.jpg
# Saved image: ./task1/men_clothing\page7_Cashmere_polo_sweater_10.jpg
# Saved image: ./task1/men_clothing\page7_Cashmere_cardigan_11.jpg
# Saved image: ./task1/men_clothing\page7_Wool_wide-leg_pants__12.jpg
# Saved image: ./task1/men_clothing\page7_Logo_cotton_jersey_T-shirt_13.jpg
# Saved image: ./task1/men_clothing\page7_Leather_straight_pants_14.jpg
# Saved image: ./task1/men_clothing\page7_Lyco_down_jacket_15.jpg
# Saved image: ./task1/men_clothing\page7_Cashmere_sweater_16.jpg
# Saved image: ./task1/men_clothing\page7_Jersey_T-shirt_17.jpg
# Saved image: ./task1/men_clothing\page7_Cotton_shorts_18.jpg
# Saved image: ./task1/men_clothing\page7_Printed_silk_shorts_19.jpg
# Saved image: ./task1/men_clothing\page7_Cotton-blend_twill_tapered_pants_20.jpg
# Saved image: ./task1/men_clothing\page7_Floral_cotton_and_silk_twill_bowling_shirt_21.jpg
# Saved image: ./task1/men_clothing\page7_Floral_cotton_shorts__22.jpg
# Saved image: ./task1/men_clothing\page7_Studded_cotton_poplin_shirt_23.jpg
# Saved image: ./task1/men_clothing\page7_Wool_blouson_24.jpg
# Saved image: ./task1/men_clothing\page7_DG_embroidered_cotton_polo_shirt_25.jpg
# Saved image: ./task1/men_clothing\page7_Double-breasted_silk_twill_blazer_26.jpg
# Saved image: ./task1/men_clothing\page7_Shelton_wool,_silk,_and_linen_blazer_27.jpg
# Saved image: ./task1/men_clothing\page7_Logo_cotton_polo_shirt_28.jpg
# Saved image: ./task1/men_clothing\page7_Logo_cotton_jersey_T-shirt_29.jpg
# Saved image: ./task1/men_clothing\page7_Pleated_gabardine_chinos_30.jpg
# Saved image: ./task1/men_clothing\page7_Double-breasted_cotton_and_cashmere_blazer_31.jpg
# Saved image: ./task1/men_clothing\page7_Cable-knit_cotton_sweater_vest_32.jpg
# Saved image: ./task1/men_clothing\page7_VLogo_cotton_jersey_T-shirt_33.jpg
# Saved image: ./task1/men_clothing\page7_Logo_cotton_polo_shirt_34.jpg
# Saved image: ./task1/men_clothing\page7_Patch-appliqué_cotton_fleece_sweatshirt_35.jpg
# Saved image: ./task1/men_clothing\page7_Kastos_quilted_down_jacket_36.jpg
# Saved image: ./task1/men_clothing\page7_Cotton_sweater_37.jpg
# Saved image: ./task1/men_clothing\page7_Wool_twill_straight_pants_38.jpg
# Saved image: ./task1/men_clothing\page7_Logo_cotton_jersey_T-shirt_39.jpg
# Saved image: ./task1/men_clothing\page7_Anagram_leather_bomber_jacket_40.jpg
# Saved image: ./task1/men_clothing\page7_Treompan_down_vest_41.jpg
# Saved image: ./task1/men_clothing\page7_Cotton_shirt_42.jpg
# Saved image: ./task1/men_clothing\page7_Cotton_western_shirt_43.jpg
# Saved image: ./task1/men_clothing\page7_Ribbed-knit_wool_and_cashmere_cardigan_44.jpg
# Saved image: ./task1/men_clothing\page7_VLogo_cotton_jersey_T-shirt_45.jpg
# Saved image: ./task1/men_clothing\page7_Double_G_cotton-blend_piqué_polo_shirt_46.jpg
# Saved image: ./task1/men_clothing\page7_Wool_and_mohair_zip-up_sweater_47.jpg
# Saved image: ./task1/men_clothing\page7_Cotton_twill_wide-leg_pants_48.jpg
# Saved image: ./task1/men_clothing\page7_Floral_cotton_Bermuda_shorts_49.jpg
# Saved image: ./task1/men_clothing\page7_Silk_twill_tapered_pants__50.jpg
# Saved image: ./task1/men_clothing\page7_Logo_cotton_jersey_track_jacket_51.jpg
# Saved image: ./task1/men_clothing\page7_Logo_cotton_piqué_polo_shirt_52.jpg
# Saved image: ./task1/men_clothing\page7_Logo_cotton_piqué_polo_shirt_53.jpg
# Saved image: ./task1/men_clothing\page7_Suede_blazer_54.jpg
# Saved image: ./task1/men_clothing\page7_DG_knitted_cotton_shirt_55.jpg
# Saved image: ./task1/men_clothing\page7_Logo_cotton_jersey_T-shirt_56.jpg
# Saved image: ./task1/men_clothing\page7_Cotton-blend_velour_track_pants_57.jpg
# Saved image: ./task1/men_clothing\page7_Fair_Isle_alpaca-blend_cardigan_58.jpg
# Saved image: ./task1/men_clothing\page7_Cable-knit_cotton_and_silk_polo_shirt__59.jpg
# Saved image: ./task1/men_clothing\page7_Givenchy_Stamp_cotton_fleece_hoodie_60.jpg
# Requesting page 8 ...
# Found 60 products on page 8
# Saved image: ./task1/men_clothing\page8_Striped_cotton_and_wool_Oxford_shirt_1.jpg
# Saved image: ./task1/men_clothing\page8_Cable-knit_cotton_and_silk_sweater_2.jpg
# Saved image: ./task1/men_clothing\page8_Logo_swim_trunks_3.jpg
# Saved image: ./task1/men_clothing\page8_Jersey_slim_pants_4.jpg
# Saved image: ./task1/men_clothing\page8_Givenchy_Paris_cotton_sweater_5.jpg
# Saved image: ./task1/men_clothing\page8_Cotton_jersey_T-shirt_6.jpg
# Saved image: ./task1/men_clothing\page8_Logo_cotton_jersey_T-shirt_7.jpg
# Saved image: ./task1/men_clothing\page8_Logo_cotton_jersey_T-shirt_8.jpg
# Saved image: ./task1/men_clothing\page8_Cotton_piqué_Western_shirt_9.jpg
# Saved image: ./task1/men_clothing\page8_Givenchy_Paris_cotton_jersey_T-shirt_10.jpg
# Saved image: ./task1/men_clothing\page8_Quilted_down_vest_11.jpg
# Saved image: ./task1/men_clothing\page8_Cotton_polo_shirt_12.jpg
# Saved image: ./task1/men_clothing\page8_Cotton_and_cashmere_sweatshirt_13.jpg
# Saved image: ./task1/men_clothing\page8_Polka-dot_quilted_jacket_14.jpg
# Saved image: ./task1/men_clothing\page8_Cotton_sweatpants_15.jpg
# Saved image: ./task1/men_clothing\page8_Cashmere_polo_sweater_16.jpg
# Saved image: ./task1/men_clothing\page8_Logo_cotton-blend_piqué_polo_shirt_17.jpg
# Saved image: ./task1/men_clothing\page8_Printed_silk_shirt_18.jpg
# Saved image: ./task1/men_clothing\page8_Treompan_down_vest_19.jpg
# Saved image: ./task1/men_clothing\page8_Cashmere_intarsia_sweater_20.jpg
# Saved image: ./task1/men_clothing\page8_Leather_jacket_21.jpg
# Saved image: ./task1/men_clothing\page8_Cotton_jersey_T-shirt_22.jpg
# Saved image: ./task1/men_clothing\page8_Cotton_hoodie_23.jpg
# Saved image: ./task1/men_clothing\page8_Anagram_ribbed-knit_cotton_T-shirt_24.jpg
# Saved image: ./task1/men_clothing\page8_Cashmere_and_silk_polo_shirt_25.jpg
# Saved image: ./task1/men_clothing\page8_Cotton_jersey_zip-up_hoodie_26.jpg
# Saved image: ./task1/men_clothing\page8_Montgenevre_wool_flannel_down_jacket_27.jpg
# Saved image: ./task1/men_clothing\page8_Cotton-blend_slim_pants_28.jpg
# Saved image: ./task1/men_clothing\page8_Cashmere_and_silk_polo_shirt_29.jpg
# Saved image: ./task1/men_clothing\page8_Cashmere_and_silk_polo_shirt_30.jpg
# Saved image: ./task1/men_clothing\page8_Tartan_checked_cotton_voile_shirt_31.jpg
# Saved image: ./task1/men_clothing\page8_Open-knit_cotton-blend_polo_shirt_32.jpg
# Saved image: ./task1/men_clothing\page8_Cotton_polo_shirt_33.jpg
# Saved image: ./task1/men_clothing\page8_Cotton_jersey_sweatpants_34.jpg
# Saved image: ./task1/men_clothing\page8_Re-Nylon-trimmed_cotton_piqué_polo_shirt_35.jpg
# Saved image: ./task1/men_clothing\page8_Wool-blend_tuxedo_36.jpg
# Saved image: ./task1/men_clothing\page8_Wool_and_mohair_tuxedo_pants_37.jpg
# Saved image: ./task1/men_clothing\page8_Cashmere-blend_sweatpants_38.jpg
# Saved image: ./task1/men_clothing\page8_Wool_and_mohair_tuxedo_jacket_39.jpg
# Saved image: ./task1/men_clothing\page8_Tibb_down_vest_40.jpg
# Saved image: ./task1/men_clothing\page8_Cotton_jersey_T-shirt_41.jpg
# Saved image: ./task1/men_clothing\page8_Moncler_Maya_down_jacket_42.jpg
# Saved image: ./task1/men_clothing\page8_VLogo_cotton_piqué_polo_shirt_43.jpg
# Saved image: ./task1/men_clothing\page8_VLogo_cotton_jersey_T-shirt_44.jpg
# Saved image: ./task1/men_clothing\page8_Cotton_polo_sweater_45.jpg
# Saved image: ./task1/men_clothing\page8_Printed_linen_canvas_bowling_shirt_46.jpg
# Saved image: ./task1/men_clothing\page8_Cashmere_and_silk_polo_sweater_47.jpg
# Saved image: ./task1/men_clothing\page8_Cotton-blend_sweatpants_48.jpg
# Saved image: ./task1/men_clothing\page8_Virgin_wool_flannel_straight_pants_49.jpg
# Saved image: ./task1/men_clothing\page8_Cashmere_cardigan_50.jpg
# Saved image: ./task1/men_clothing\page8_Cassandre_cotton_and_linen_overshirt_51.jpg
# Saved image: ./task1/men_clothing\page8_Cotton-blend_jersey_sweatpants_52.jpg
# Saved image: ./task1/men_clothing\page8_Dyllan_cotton_velvet_blazer_53.jpg
# Saved image: ./task1/men_clothing\page8_Cassandre_cotton-blend_T-shirt_54.jpg
# Saved image: ./task1/men_clothing\page8_Epine_down_jacket_55.jpg
# Saved image: ./task1/men_clothing\page8_Vigeon_down_jacket_56.jpg
# Saved image: ./task1/men_clothing\page8_Checked_cotton_jacket_57.jpg
# Saved image: ./task1/men_clothing\page8_Mid-rise_slim_jeans_58.jpg
# Saved image: ./task1/men_clothing\page8_Cashmere_and_silk_polo_sweater_59.jpg
# Saved image: ./task1/men_clothing\page8_Virgin_wool_straight_pants_60.jpg
# Requesting page 9 ...
# Found 60 products on page 9
# Saved image: ./task1/men_clothing\page9_Cotton_velvet_sweatpants_1.jpg
# Saved image: ./task1/men_clothing\page9_Suede_down_vest_2.jpg
# Saved image: ./task1/men_clothing\page9_Jersey_Henley_shirt_3.jpg
# Saved image: ./task1/men_clothing\page9_Cotton-blend_T-shirt_4.jpg
# Saved image: ./task1/men_clothing\page9_Baudinet_quilted_down_jacket_5.jpg
# Saved image: ./task1/men_clothing\page9_Cotton-blend_straight_pants_6.jpg
# Saved image: ./task1/men_clothing\page9_Linen_tapered_pants_7.jpg
# Saved image: ./task1/men_clothing\page9_Logo_cotton_jersey_T-shirt_8.jpg
# Saved image: ./task1/men_clothing\page9_Virgin_wool_tapered_pants_9.jpg
# Saved image: ./task1/men_clothing\page9_Cotton_hoodie_10.jpg
# Saved image: ./task1/men_clothing\page9_Wool_and_cashmere_sweater_11.jpg
# Saved image: ./task1/men_clothing\page9_Logo_cotton_fleece_hoodie_12.jpg
# Saved image: ./task1/men_clothing\page9_Cashmere-blend_sweatpants_13.jpg
# Saved image: ./task1/men_clothing\page9_Logo_cotton_piqué_polo_shirt_14.jpg
# Saved image: ./task1/men_clothing\page9_Toute_La_V_cotton_poplin_bowling_shirt_15.jpg
# Saved image: ./task1/men_clothing\page9_Cotton_and_silk_twill_sweatpants_16.jpg
# Saved image: ./task1/men_clothing\page9_Double-breasted_linen_blazer_17.jpg
# Saved image: ./task1/men_clothing\page9_Logo_cotton_jersey_T-shirt_18.jpg
# Saved image: ./task1/men_clothing\page9_Cashmere_polo_sweater_19.jpg
# Saved image: ./task1/men_clothing\page9_Embroidered_cotton-blend_socks_20.jpg

# %%
# This code scrapes 500 women clothing images in 1024*1024 resolution
import os
import requests
import time
import re

url = "https://api.mytheresa.com/api"

headers = {
    "accept": "*/*",
    "accept-language": "en",
    "content-type": "text/plain;charset=UTF-8",
    "origin": "https://www.mytheresa.com",
    "priority": "u=1, i",
    "referer": "https://www.mytheresa.com/",
    "sec-ch-ua": '"Not;A=Brand";v="99", "Microsoft Edge";v="139", "Chromium";v="139"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-site",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36 Edg/139.0.0.0",
    "x-country": "GB",
    "x-region": "BY",
    "x-section": "women",
    "x-store": "GB",
}

cookies = {
    "mt_consent": "4",
}

json_query = """query XProductListingPageQuery($categories: [String], $colors: [String], $designers: [String], $fta: Boolean, $materials: [String], $page: Int, $patterns: [String], $reductionRange: [String], $saleStatus: SaleStatusEnum, $size: Int, $sizesHarmonized: [String], $slug: String, $sort: String) {
  xProductListingPage(categories: $categories, colors: $colors, designers: $designers, fta: $fta, materials: $materials, page: $page, patterns: $patterns, reductionRange: $reductionRange, saleStatus: $saleStatus, size: $size, sizesHarmonized: $sizesHarmonized, slug: $slug, sort: $sort) {
    products {
      name
      displayImages
    }
  }
}"""

save_dir = "./women_clothing"
os.makedirs(save_dir, exist_ok=True)

def force_1024_image_url(url):
    # Replace segments like /1088/1088/ or /720/720/ with /1024/1024/
    return re.sub(r'/\d{3,4}/\d{3,4}/', '/1024/1024/', url)

def download_images_for_page(page, max_images=None):
    variables = {
        "categories": [],
        "colors": [],
        "designers": [],
        "fta": None,
        "materials": [],
        "page": page,
        "patterns": [],
        "reductionRange": [],
        "saleStatus": None,
        "size": 60,
        "sizesHarmonized": [],
        "slug": "/clothing",
        "sort": None,
    }

    json_data = {
        "query": json_query,
        "variables": variables,
    }

    print(f"Requesting page {page} ...")
    response = requests.post(url, headers=headers, cookies=cookies, json=json_data)
    if response.status_code != 200:
        print(f"Failed to fetch page {page}: status {response.status_code}")
        return

    data = response.json()
    products = data.get('data', {}).get('xProductListingPage', {}).get('products', [])
    print(f"Found {len(products)} products on page {page}")

    count = 0
    for idx, product in enumerate(products, start=1):
        if max_images and count >= max_images:
            break
        images = product.get('displayImages', [])
        if not images:
            continue
        img_url = force_1024_image_url(images[0])  # Enforce 1024x1024 image URL

        try:
            img_response = requests.get(img_url)
            img_response.raise_for_status()
            ext = img_url.split('.')[-1].split('?')[0]
            safe_name = product.get('name', 'product').replace(' ', '_').replace('/', '_')
            filename = f"page{page}_{safe_name}_{idx}.{ext}"
            filepath = os.path.join(save_dir, filename)
            with open(filepath, 'wb') as f:
                f.write(img_response.content)
            print(f"Saved image: {filepath}")
            count += 1
            time.sleep(0.1)  # small delay to be polite
        except Exception as e:
            print(f"Failed to download image {img_url}: {e}")

# Download full pages 1 to 8
for page_num in range(1, 9):
    download_images_for_page(page_num)

# Download only 20 images from page 9
download_images_for_page(9, max_images=20)
# Out:
# Requesting page 1 ...
# Found 60 products on page 1
# Saved image: ./task1/women_clothing\page1_Arwen_oversized_coat_1.jpg
# Saved image: ./task1/women_clothing\page1_Belted_wool_and_cashmere_coat_2.jpg
# Saved image: ./task1/women_clothing\page1_Ment_Bengal_stripe_cotton_poplin_shirt_3.jpg
# Saved image: ./task1/women_clothing\page1_Cotton_corduroy_wide-leg_pants_4.jpg
# Saved image: ./task1/women_clothing\page1_Ness_denim_jacket_5.jpg
# Saved image: ./task1/women_clothing\page1_Carlyl_mid-rise_straight_jeans_6.jpg
# Saved image: ./task1/women_clothing\page1_Cable-knit_cashmere_zip-up_cardigan_7.jpg
# Saved image: ./task1/women_clothing\page1_Cable-knit_wool_and_cashmere_turtleneck_sweater_8.jpg
# Saved image: ./task1/women_clothing\page1_Hypnotic_printed_caped_maxi_dress_9.jpg
# Saved image: ./task1/women_clothing\page1_Asymmetric_draped_gown_10.jpg
# Saved image: ./task1/women_clothing\page1_Double-breasted_chambray_blazer_11.jpg
# Saved image: ./task1/women_clothing\page1_Chambray_straight_pants_12.jpg
# Saved image: ./task1/women_clothing\page1_Iverness_knitted_cashmere_top_13.jpg
# Saved image: ./task1/women_clothing\page1_Paisley_high-rise_bootcut_jeans_14.jpg
# Saved image: ./task1/women_clothing\page1_Margan_cotton_poplin_shirt_15.jpg
# Saved image: ./task1/women_clothing\page1_Wide-leg_jeans_16.jpg
# Saved image: ./task1/women_clothing\page1_Off-shoulder_pleated_bustier_gown_17.jpg
# Saved image: ./task1/women_clothing\page1_Coco_embroidered_ramie_maxi_dress_18.jpg
# Saved image: ./task1/women_clothing\page1_Hypnotic_paisley_silk_shirt_19.jpg
# Saved image: ./task1/women_clothing\page1_Hypnotic_printed_silk_wide-leg_pants_20.jpg
# Saved image: ./task1/women_clothing\page1_Crepe_Couture_bow-detail_minidress_21.jpg
# Saved image: ./task1/women_clothing\page1_Crepe_Couture_embroidered_minidress_22.jpg
# Saved image: ./task1/women_clothing\page1_Hypnotic_floral_ramie_blouse_23.jpg
# Saved image: ./task1/women_clothing\page1_Hypnotic_floral_linen_pencil_skirt_24.jpg
# Saved image: ./task1/women_clothing\page1_Hypnotic_floral_linen_and_silk_minidress_25.jpg
# Saved image: ./task1/women_clothing\page1_Guipure_lace_gown_26.jpg
# Saved image: ./task1/women_clothing\page1_VLogo_checked_wool-blend_jacket_27.jpg
# Saved image: ./task1/women_clothing\page1_VLogo_checked_wool-blend_miniskirt_28.jpg
# Saved image: ./task1/women_clothing\page1_Checked_cropped_wool-blend_shirt_29.jpg
# Saved image: ./task1/women_clothing\page1_Double-breasted_cotton_cape_30.jpg
# Saved image: ./task1/women_clothing\page1_Carpazi_cotton_shirt_31.jpg
# Saved image: ./task1/women_clothing\page1_Printed_silk_maxi_skirt_32.jpg
# Saved image: ./task1/women_clothing\page1_Hypnotic_linen_and_silk_organza_midi_dress_33.jpg
# Saved image: ./task1/women_clothing\page1_Sunray_printed_midi_dress_34.jpg
# Saved image: ./task1/women_clothing\page1_Down_jacket_35.jpg
# Saved image: ./task1/women_clothing\page1_Pleated_mohair_and_wool_miniskirt_36.jpg
# Saved image: ./task1/women_clothing\page1_Printed_blouse_37.jpg
# Saved image: ./task1/women_clothing\page1_Printed_wide-leg_pants_38.jpg
# Saved image: ./task1/women_clothing\page1_Double_G_wool-blend_tweed_coat_39.jpg
# Saved image: ./task1/women_clothing\page1_Double_G_wool-blend_tweed_minidress_40.jpg
# Saved image: ./task1/women_clothing\page1_Argyle_cashmere_polo_sweater_41.jpg
# Saved image: ./task1/women_clothing\page1_Varda_leather_maxi_skirt_42.jpg
# Saved image: ./task1/women_clothing\page1_Horsebit_wool_and_cashmere_sweater_43.jpg
# Saved image: ./task1/women_clothing\page1_High-rise_balloon_jeans_44.jpg
# Saved image: ./task1/women_clothing\page1_Single-breasted_wool_coat_45.jpg
# Saved image: ./task1/women_clothing\page1_High-rise_wide-leg_jeans_46.jpg
# Saved image: ./task1/women_clothing\page1_Denim_midi_dress_47.jpg
# Saved image: ./task1/women_clothing\page1_Hypnotic_floral_lace_midi_dress_48.jpg
# Saved image: ./task1/women_clothing\page1_Layered_cashmere_sweater_49.jpg
# Saved image: ./task1/women_clothing\page1_Pinstripe_virgin_wool_wide-leg_pants_50.jpg
# Saved image: ./task1/women_clothing\page1_Hypnotic_ruffled_top_51.jpg
# Saved image: ./task1/women_clothing\page1_Hypnotic_ruffled_maxi_skirt_52.jpg
# Saved image: ./task1/women_clothing\page1_Belted_hooded_denim_jacket_53.jpg
# Saved image: ./task1/women_clothing\page1_Atalanta_cropped_cardigan_54.jpg
# Saved image: ./task1/women_clothing\page1_Zigzag__wool_and_cotton_polo_sweater_55.jpg
# Saved image: ./task1/women_clothing\page1_Wool_and_cotton_straight_pants_56.jpg
# Saved image: ./task1/women_clothing\page1_Elway_printed_jersey_T-shirt__57.jpg
# Saved image: ./task1/women_clothing\page1_Page_wide-leg_jeans_58.jpg
# Saved image: ./task1/women_clothing\page1_Chez_Valentino_virgin_wool_sweater_59.jpg
# Saved image: ./task1/women_clothing\page1_Ribbed-knit_alpaca_and_yak_wool_cardigan_60.jpg
# Requesting page 2 ...
# Found 60 products on page 2
# Saved image: ./task1/women_clothing\page2_Logo_cotton_fleece_zip-up_sweatshirt_1.jpg
# Saved image: ./task1/women_clothing\page2_Horsebit_wool_shirt_dress_2.jpg
# Saved image: ./task1/women_clothing\page2_Gathered_minidress_3.jpg
# Saved image: ./task1/women_clothing\page2_Sabine_cashmere_sweater_4.jpg
# Saved image: ./task1/women_clothing\page2_Julianne_high-rise_wide-leg_pants_5.jpg
# Saved image: ./task1/women_clothing\page2_Horsebit_oversized_silk_shirt_6.jpg
# Saved image: ./task1/women_clothing\page2_Horsebit_high-rise_silk_palazzo_pants_7.jpg
# Saved image: ./task1/women_clothing\page2_Winston_twill_wool_coat_8.jpg
# Saved image: ./task1/women_clothing\page2_Ruched_jersey_midi_dress_9.jpg
# Saved image: ./task1/women_clothing\page2_Web_Stripe_cashmere_and_silk_polo_sweater_10.jpg
# Saved image: ./task1/women_clothing\page2_Gargano_linen_polo_shirt_11.jpg
# Saved image: ./task1/women_clothing\page2_GG_tweed_blazer_12.jpg
# Saved image: ./task1/women_clothing\page2_GG_tweed_miniskirt_13.jpg
# Saved image: ./task1/women_clothing\page2_Najac_denim_jacket_14.jpg
# Saved image: ./task1/women_clothing\page2_Tribeca_barrel-leg_jeans_15.jpg
# Saved image: ./task1/women_clothing\page2_Embroidered_sequined_tulle_gown_16.jpg
# Saved image: ./task1/women_clothing\page2_Noor_silk_tulle_corset_gown_17.jpg
# Saved image: ./task1/women_clothing\page2_Halterneck_striped_cotton_midi_dress_18.jpg
# Saved image: ./task1/women_clothing\page2_Floral_silk_midi_dress_19.jpg
# Saved image: ./task1/women_clothing\page2_Rhiannon_printed_ramie_blouse_20.jpg
# Saved image: ./task1/women_clothing\page2_Rhiannon_paisley_embroidered_linen_shorts_21.jpg
# Saved image: ./task1/women_clothing\page2_Cashmere_and_silk_cardigan_22.jpg
# Saved image: ./task1/women_clothing\page2_Cashmere_and_silk_top_23.jpg
# Saved image: ./task1/women_clothing\page2_Noélie_embellished_satin_gown_24.jpg
# Saved image: ./task1/women_clothing\page2_Floral_linen_midi_dress_25.jpg
# Saved image: ./task1/women_clothing\page2_Embellished_silk_maxi_dress_26.jpg
# Saved image: ./task1/women_clothing\page2_Printed_scarf-detail_silk_maxi_dress_27.jpg
# Saved image: ./task1/women_clothing\page2_Cropped_shearling-trimmed_wool-blend_coat_28.jpg
# Saved image: ./task1/women_clothing\page2_Maxine_suede_straight_pants_29.jpg
# Saved image: ./task1/women_clothing\page2_Intarsia_alpaca_and_wool-blend_sweater_30.jpg
# Saved image: ./task1/women_clothing\page2_Logo_knitted_cashmere_and_silk_T-shirt_31.jpg
# Saved image: ./task1/women_clothing\page2_Draped_satin_gown_32.jpg
# Saved image: ./task1/women_clothing\page2_Gathered_jersey_gown_33.jpg
# Saved image: ./task1/women_clothing\page2_Cotton_corduroy_wide-leg_pants__34.jpg
# Saved image: ./task1/women_clothing\page2_Sony_cashmere_sweater_35.jpg
# Saved image: ./task1/women_clothing\page2_Bilbao_Bermuda_shorts_36.jpg
# Saved image: ./task1/women_clothing\page2_Wool_and_linen-blend_blazer_37.jpg
# Saved image: ./task1/women_clothing\page2_Daisy_Sangallo_belted_cotton_shirt_dress_38.jpg
# Saved image: ./task1/women_clothing\page2_Cropped_shearling-trimmed_leather_jacket_39.jpg
# Saved image: ./task1/women_clothing\page2_Wool_and_linen-blend_midi_skirt_40.jpg
# Saved image: ./task1/women_clothing\page2_Silk_jacquard_maxi_dress_41.jpg
# Saved image: ./task1/women_clothing\page2_Plus_De_Pois_silk_crepon_chiffon_gown_42.jpg
# Saved image: ./task1/women_clothing\page2_Embroidered_cotton-blend_bodysuit_43.jpg
# Saved image: ./task1/women_clothing\page2_Asta_cashmere_maxi_skirt_44.jpg
# Saved image: ./task1/women_clothing\page2_Lexia_cashmere_sweater_45.jpg
# Saved image: ./task1/women_clothing\page2_Coleman_slim_pants_46.jpg
# Saved image: ./task1/women_clothing\page2_Canvas_jacket_47.jpg
# Saved image: ./task1/women_clothing\page2_VLogo_canvas_midi_skirt_48.jpg
# Saved image: ./task1/women_clothing\page2_Cotton_gabardine_trench_coat_49.jpg
# Saved image: ./task1/women_clothing\page2_Belted_reversible_shearling_coat_50.jpg
# Saved image: ./task1/women_clothing\page2_Lucille_sequined_strapless_gown_51.jpg
# Saved image: ./task1/women_clothing\page2_Asymmetric_off-shoulder_bustier_gown_52.jpg
# Saved image: ./task1/women_clothing\page2_Shirred_cropped_lace-trimmed_silk_blouse_53.jpg
# Saved image: ./task1/women_clothing\page2_Leather_midi_skirt_54.jpg
# Saved image: ./task1/women_clothing\page2_Logo_floral_brocade_minidress_55.jpg
# Saved image: ./task1/women_clothing\page2_Majolica_cotton_poplin_bustier_dress_56.jpg
# Saved image: ./task1/women_clothing\page2_Jacquard_lace-trimmed_silk_midi_dress_57.jpg
# Saved image: ./task1/women_clothing\page2_Glenda_embroidered_crêpe_midi_dress_58.jpg
# Saved image: ./task1/women_clothing\page2_Shearling_jacket_59.jpg
# Saved image: ./task1/women_clothing\page2_Pleated_denim_midi_skirt_60.jpg
# Requesting page 3 ...
# Found 60 products on page 3
# Saved image: ./task1/women_clothing\page3_Floral_silk_crêpe_de_chine_maxi_dress_1.jpg
# Saved image: ./task1/women_clothing\page3_Floral_pleated_midi_dress_2.jpg
# Saved image: ./task1/women_clothing\page3_Floral_silk_blouse_3.jpg
# Saved image: ./task1/women_clothing\page3_Leather_pencil_skirt_4.jpg
# Saved image: ./task1/women_clothing\page3_Checked_pleated_silk_charmeuse_midi_dress_5.jpg
# Saved image: ./task1/women_clothing\page3_Silk,_wool,_and_cashmere_shirt_dress_6.jpg
# Saved image: ./task1/women_clothing\page3_Checked_cropped_wool-blend_jacket_7.jpg
# Saved image: ./task1/women_clothing\page3_High-rise_wide-leg_jeans_8.jpg
# Saved image: ./task1/women_clothing\page3_Checked_double-breasted_virgin_wool_coat_9.jpg
# Saved image: ./task1/women_clothing\page3_Ruffled_lace_and_linen_minidress_10.jpg
# Saved image: ./task1/women_clothing\page3_Corduroy-trimmed_denim_jacket_11.jpg
# Saved image: ./task1/women_clothing\page3_Mid-rise_cotton_and_silk_jeans_12.jpg
# Saved image: ./task1/women_clothing\page3_Cropped_cotton_gabardine_trench_coat_13.jpg
# Saved image: ./task1/women_clothing\page3_Leather_jacket_14.jpg
# Saved image: ./task1/women_clothing\page3_Parana_down_jacket_15.jpg
# Saved image: ./task1/women_clothing\page3_Terry_sweatpants_16.jpg
# Saved image: ./task1/women_clothing\page3_Floral_cretonne_midi_dress_17.jpg
# Saved image: ./task1/women_clothing\page3_Cutout_printed_midi_dress_18.jpg
# Saved image: ./task1/women_clothing\page3_Liese_pleated_silk_satin_blouse_19.jpg
# Saved image: ./task1/women_clothing\page3_Gaelle_tiered_silk_satin_maxi_skirt_20.jpg
# Saved image: ./task1/women_clothing\page3_Flamenco_cotton_and_cashmere_hoodie_21.jpg
# Saved image: ./task1/women_clothing\page3_Checked_gathered_cotton_miniskirt_22.jpg
# Saved image: ./task1/women_clothing\page3_Crystal-embellished_tiered_gown_23.jpg
# Saved image: ./task1/women_clothing\page3_Zig_Zag_halterneck_maxi_dress_24.jpg
# Saved image: ./task1/women_clothing\page3_Kiera_printed_silk_shirt_dress_25.jpg
# Saved image: ./task1/women_clothing\page3_Draped_sheer_midi_dress_26.jpg
# Saved image: ./task1/women_clothing\page3_Wool_and_cotton-blend_turtleneck_sweater_27.jpg
# Saved image: ./task1/women_clothing\page3_Leather_midi_skirt_28.jpg
# Saved image: ./task1/women_clothing\page3_Wool_and_cotton-blend_jacket_29.jpg
# Saved image: ./task1/women_clothing\page3_Cropped_mid-rise_wide-leg_jeans_30.jpg
# Saved image: ./task1/women_clothing\page3_Latitude_gathered_ruffled_gown_31.jpg
# Saved image: ./task1/women_clothing\page3_Tara_sequined_bustier_dress_32.jpg
# Saved image: ./task1/women_clothing\page3_Silk,_wool,_and_cashmere_cardigan_33.jpg
# Saved image: ./task1/women_clothing\page3_2006F_distressed_wide-leg_jeans_34.jpg
# Saved image: ./task1/women_clothing\page3_Paisley_pleated_minidress_35.jpg
# Saved image: ./task1/women_clothing\page3_DG_distressed_wool-blend_tweed_minidress_36.jpg
# Saved image: ./task1/women_clothing\page3_Cotton_jersey_polo_sweater_dress_37.jpg
# Saved image: ./task1/women_clothing\page3_Wool-blend_minidress_38.jpg
# Saved image: ./task1/women_clothing\page3_Tess_Long_low-rise_wide-leg_jeans_39.jpg
# Saved image: ./task1/women_clothing\page3_Cropped_lace-trimmed_cotton_T-shirt_40.jpg
# Saved image: ./task1/women_clothing\page3_Wool_flared_pants_41.jpg
# Saved image: ./task1/women_clothing\page3_Majolica_silk-blend_minidress__42.jpg
# Saved image: ./task1/women_clothing\page3_Cotton_and_silk-blend_minidress_43.jpg
# Saved image: ./task1/women_clothing\page3_Floral_gathered_midi_dress_44.jpg
# Saved image: ./task1/women_clothing\page3_Embellished_caped_satin_crêpe_midi_dress_45.jpg
# Saved image: ./task1/women_clothing\page3_Embroidered_cotton-blend_cardigan_46.jpg
# Saved image: ./task1/women_clothing\page3_High-rise_wool_wide-leg_pants_47.jpg
# Saved image: ./task1/women_clothing\page3_Floral-appliqué_wool-blend_midi_dress_48.jpg
# Saved image: ./task1/women_clothing\page3_Sequined_strapless_gown_49.jpg
# Saved image: ./task1/women_clothing\page3_Cotton_poplin_shirt_50.jpg
# Saved image: ./task1/women_clothing\page3_Mid-rise_wide-leg_jeans_51.jpg
# Saved image: ./task1/women_clothing\page3_Scarf-detail_cashmere_sweater_52.jpg
# Saved image: ./task1/women_clothing\page3_Cotton-blend_bouclé_pencil_skirt_53.jpg
# Saved image: ./task1/women_clothing\page3_Argyle_knitted_cashmere_top_54.jpg
# Saved image: ./task1/women_clothing\page3_Virgin_wool_polo_sweater_55.jpg
# Saved image: ./task1/women_clothing\page3_Gia_ribbed-knit_wool_and_cashmere_maxi_dress_56.jpg
# Saved image: ./task1/women_clothing\page3_Cotton-blend_jersey_polo_dress_57.jpg
# Saved image: ./task1/women_clothing\page3_Tie-neck_cotton_shirt_dress_58.jpg
# Saved image: ./task1/women_clothing\page3_Distressed_shorts_59.jpg
# Saved image: ./task1/women_clothing\page3_Maury_faux-fur_leather_jacket_60.jpg
# Requesting page 4 ...
# Found 60 products on page 4
# Saved image: ./task1/women_clothing\page4_Astley_cropped_leather_jacket__1.jpg
# Saved image: ./task1/women_clothing\page4_Kasos_draped_cashmere_maxi_dress_2.jpg
# Saved image: ./task1/women_clothing\page4_Gathered_gown_3.jpg
# Saved image: ./task1/women_clothing\page4_Gretas_knitted_cotton_cardigan_4.jpg
# Saved image: ./task1/women_clothing\page4_Cotton_barrel-leg_pants_5.jpg
# Saved image: ./task1/women_clothing\page4_Belted_herringbone_wool-blend_blazer_6.jpg
# Saved image: ./task1/women_clothing\page4_Monili_high-rise_wide-leg_jeans_7.jpg
# Saved image: ./task1/women_clothing\page4_Belted_wool_and_silk_midi_dress_8.jpg
# Saved image: ./task1/women_clothing\page4_Belted_bouclé_maxi_dress_9.jpg
# Saved image: ./task1/women_clothing\page4_Ribbed-knit_silk_sweater_10.jpg
# Saved image: ./task1/women_clothing\page4_Floral_asymmetric_wrap_skirt_11.jpg
# Saved image: ./task1/women_clothing\page4_Everheart_cashmere_cardigan_12.jpg
# Saved image: ./task1/women_clothing\page4_Four_Stitches_virgin_wool_cardigan_13.jpg
# Saved image: ./task1/women_clothing\page4_Stef_wool-blend_cardigan_14.jpg
# Saved image: ./task1/women_clothing\page4_Alex_mid-rise_wide-leg_jeans_15.jpg
# Saved image: ./task1/women_clothing\page4_Shrunken_Boiled_knitted_jacket_16.jpg
# Saved image: ./task1/women_clothing\page4_Eva_high-rise_wide-leg_jeans_17.jpg
# Saved image: ./task1/women_clothing\page4_Off-shoulder_crêpe_bustier_gown_18.jpg
# Saved image: ./task1/women_clothing\page4_Elysia_embellished_lace_gown_19.jpg
# Saved image: ./task1/women_clothing\page4_Nalina_embellished_georgette_gown_20.jpg
# Saved image: ./task1/women_clothing\page4_Embroidered_smocked_linen_midi_dress_21.jpg
# Saved image: ./task1/women_clothing\page4_Leone_draped_vest_22.jpg
# Saved image: ./task1/women_clothing\page4_Leone_mid-rise_wide-leg_pants__23.jpg
# Saved image: ./task1/women_clothing\page4_Lace-trimmed_cotton_tank_top_24.jpg
# Saved image: ./task1/women_clothing\page4_Striped_cotton_poplin_wide-leg_pants_25.jpg
# Saved image: ./task1/women_clothing\page4_Irina_draped_gown_26.jpg
# Saved image: ./task1/women_clothing\page4_Faranna_crystal-embellished_crêpe_gown_27.jpg
# Saved image: ./task1/women_clothing\page4_Arola_knitted_cotton_polo_dress_28.jpg
# Saved image: ./task1/women_clothing\page4_Broderie_anglaise_cotton_shirt_dress_29.jpg
# Saved image: ./task1/women_clothing\page4_Suede_overshirt_30.jpg
# Saved image: ./task1/women_clothing\page4_Dane_wide-leg_jeans_31.jpg
# Saved image: ./task1/women_clothing\page4_Jackson_leather_jacket_32.jpg
# Saved image: ./task1/women_clothing\page4_Paisley_jacquard_midi_skirt_33.jpg
# Saved image: ./task1/women_clothing\page4_Cable-knit_wool_and_cashmere_cardigan_34.jpg
# Saved image: ./task1/women_clothing\page4_Anagram_ribbed-knit_silk_tank_top_35.jpg
# Saved image: ./task1/women_clothing\page4_Wool_and_cashmere_cardigan_36.jpg
# Saved image: ./task1/women_clothing\page4_Poldo_virgin_wool_wrap_coat_37.jpg
# Saved image: ./task1/women_clothing\page4_High-rise_wool_wide-leg_pants_38.jpg
# Saved image: ./task1/women_clothing\page4_Cascadian_leopard-print_linen_midi_dress_39.jpg
# Saved image: ./task1/women_clothing\page4_Anagram_cotton_piqué_polo_shirt_40.jpg
# Saved image: ./task1/women_clothing\page4_Polka-dot_tiered_midi_dress_41.jpg
# Saved image: ./task1/women_clothing\page4_Logo_wool_mid-rise_straight_pants__42.jpg
# Saved image: ./task1/women_clothing\page4_Rhiannon_gathered_paisley_cotton_midi_dress_43.jpg
# Saved image: ./task1/women_clothing\page4_Anagram_cotton-blend_T-shirt_44.jpg
# Saved image: ./task1/women_clothing\page4_Chez_Valentino_cotton_jersey_T-shirt_45.jpg
# Saved image: ./task1/women_clothing\page4_Orione_midi_dress_46.jpg
# Saved image: ./task1/women_clothing\page4_Ascension_ruffled_denim_minidress_47.jpg
# Saved image: ./task1/women_clothing\page4_Orione_midi_dress_48.jpg
# Saved image: ./task1/women_clothing\page4_Lucky_floral_tiered_cotton_maxi_dress_49.jpg
# Saved image: ./task1/women_clothing\page4_Tank_gathered_cotton-blend_midi_dress_50.jpg
# Saved image: ./task1/women_clothing\page4_Rhiannon_floral_cotton_bustier_dress_51.jpg
# Saved image: ./task1/women_clothing\page4_Cable-knit_wool_and_cashmere_cardigan_52.jpg
# Saved image: ./task1/women_clothing\page4_Lucky_Picnic_floral_cotton_maxi_dress_53.jpg
# Saved image: ./task1/women_clothing\page4_Slogan_cotton_jersey_T-shirt_54.jpg
# Saved image: ./task1/women_clothing\page4_Anagram_cotton-blend_jersey_T-shirt_55.jpg
# Saved image: ./task1/women_clothing\page4_Lucky_denim_midi_dress_56.jpg
# Saved image: ./task1/women_clothing\page4_Polka-dot_ruffled_minidress_57.jpg
# Saved image: ./task1/women_clothing\page4_Coco_floral_cotton_minidress_58.jpg
# Saved image: ./task1/women_clothing\page4_Cascadian_leopard-print_linen_tunic_59.jpg
# Saved image: ./task1/women_clothing\page4_Jour_cotton_chambray_wide-leg_pants_60.jpg
# Requesting page 5 ...
# Found 60 products on page 5
# Saved image: ./task1/women_clothing\page5_Poldo_virgin_wool_wrap_coat_1.jpg
# Saved image: ./task1/women_clothing\page5_Floria_virgin_wool_straight_pants_2.jpg
# Saved image: ./task1/women_clothing\page5_Ascension_floral_ruffled_cotton_midi_dress_3.jpg
# Saved image: ./task1/women_clothing\page5_Laura_jacket_4.jpg
# Saved image: ./task1/women_clothing\page5_Lucky_floral_linen_lace_maxi_dress_5.jpg
# Saved image: ./task1/women_clothing\page5_Cotton-blend_Henley_shirt_6.jpg
# Saved image: ./task1/women_clothing\page5_Rhiannon_scalloped_linen_midi_dress_7.jpg
# Saved image: ./task1/women_clothing\page5_Anagram_wide-leg_jeans_8.jpg
# Saved image: ./task1/women_clothing\page5_Monza_cotton-blend_jersey_sweatshirt_9.jpg
# Saved image: ./task1/women_clothing\page5_Plata_faux_leather_midi_skirt_10.jpg
# Saved image: ./task1/women_clothing\page5_Cashair_cashmere_sweater_11.jpg
# Saved image: ./task1/women_clothing\page5_Ascension_floral_linen_midi_dress_12.jpg
# Saved image: ./task1/women_clothing\page5_Belted_virgin_wool_coat_13.jpg
# Saved image: ./task1/women_clothing\page5_Chez_Valentino_striped_cotton_jersey_top_14.jpg
# Saved image: ./task1/women_clothing\page5_Cotton-blend_Henley_shirt_15.jpg
# Saved image: ./task1/women_clothing\page5_Coco_bow-detail_floral_linen_midi_dress_16.jpg
# Saved image: ./task1/women_clothing\page5_Cashair_cashmere_turtleneck_sweater_17.jpg
# Saved image: ./task1/women_clothing\page5_Floral_lace_bodysuit_18.jpg
# Saved image: ./task1/women_clothing\page5_Chez_Valentino_cotton_jersey_T-shirt_19.jpg
# Saved image: ./task1/women_clothing\page5_Titty_wool_wide-leg_pants_20.jpg
# Saved image: ./task1/women_clothing\page5_Plata_faux_leather_midi_skirt_21.jpg
# Saved image: ./task1/women_clothing\page5_Cashair_cashmere_cardigan_22.jpg
# Saved image: ./task1/women_clothing\page5_Pleated_printed_cotton_midi_skirt_23.jpg
# Saved image: ./task1/women_clothing\page5_Cotton_jersey_T-shirt_24.jpg
# Saved image: ./task1/women_clothing\page5_Ribbed-knit_wool_polo_shirt_25.jpg
# Saved image: ./task1/women_clothing\page5_Bow-detail_cotton_denim_minidress_26.jpg
# Saved image: ./task1/women_clothing\page5_Belted_virgin_wool_coat_27.jpg
# Saved image: ./task1/women_clothing\page5_High-rise_wool_midi_skirt_28.jpg
# Saved image: ./task1/women_clothing\page5_Cashair_cashmere_cardigan_29.jpg
# Saved image: ./task1/women_clothing\page5_Roseto_alpaca_and_wool_coat_30.jpg
# Saved image: ./task1/women_clothing\page5_x_On_technical_jersey_tights_31.jpg
# Saved image: ./task1/women_clothing\page5_Pleated_ruffled_minidress_32.jpg
# Saved image: ./task1/women_clothing\page5_Cascadian_floral_strapless_midi_dress_33.jpg
# Saved image: ./task1/women_clothing\page5_Wool-blend_cardigan_34.jpg
# Saved image: ./task1/women_clothing\page5_Cotton_and_silk_T-shirt_35.jpg
# Saved image: ./task1/women_clothing\page5_High-rise_wool_straight_pants_36.jpg
# Saved image: ./task1/women_clothing\page5_Logo_cotton-blend_minidress_37.jpg
# Saved image: ./task1/women_clothing\page5_Anagram_cotton-blend_minidress_38.jpg
# Saved image: ./task1/women_clothing\page5_Livio_wool_and_cashmere_wide-leg_pants_39.jpg
# Saved image: ./task1/women_clothing\page5_Cashair_cashmere_turtleneck_sweater_40.jpg
# Saved image: ./task1/women_clothing\page5_Cashair_cashmere_sweater_41.jpg
# Saved image: ./task1/women_clothing\page5_Cashmere_top_42.jpg
# Saved image: ./task1/women_clothing\page5_John_barrel-leg_jeans_43.jpg
# Saved image: ./task1/women_clothing\page5_Coco_cotton_terry_shorts_44.jpg
# Saved image: ./task1/women_clothing\page5_Ribbed-knit_wool_polo_shirt_45.jpg
# Saved image: ./task1/women_clothing\page5_Hypnotic_snake-print_silk_shirt_46.jpg
# Saved image: ./task1/women_clothing\page5_Poldo_wool_wrap_coat_47.jpg
# Saved image: ./task1/women_clothing\page5_Morissey_wool_and_cotton_flared_pants_48.jpg
# Saved image: ./task1/women_clothing\page5_Lukas_virgin_wool_peacoat_49.jpg
# Saved image: ./task1/women_clothing\page5_Paul_double-breasted_virgin_wool_coat_50.jpg
# Saved image: ./task1/women_clothing\page5_Silk_blouse_51.jpg
# Saved image: ./task1/women_clothing\page5_Coleman_slim_pants_52.jpg
# Saved image: ./task1/women_clothing\page5_Potenza_cotton-blend_fleece_sweatpants_53.jpg
# Saved image: ./task1/women_clothing\page5_Cotton_jersey_T-shirt__54.jpg
# Saved image: ./task1/women_clothing\page5_Ribbed-knit_pleated_wool_midi_dress_55.jpg
# Saved image: ./task1/women_clothing\page5_VGold_jersey_shorts_56.jpg
# Saved image: ./task1/women_clothing\page5_Cashair_cashmere_sweater_57.jpg
# Saved image: ./task1/women_clothing\page5_Curoe_virgin_wool_wrap_coat_58.jpg
# Saved image: ./task1/women_clothing\page5_Cotton_and_silk_jersey_T-shirt_59.jpg
# Saved image: ./task1/women_clothing\page5_Lavinia_cotton_jersey_T-shirt_60.jpg
# Requesting page 6 ...
# Found 60 products on page 6
# Saved image: ./task1/women_clothing\page6_Lukas_double-breasted_virgin_wool_peacoat_1.jpg
# Saved image: ./task1/women_clothing\page6_Jersey_midi_dress_2.jpg
# Saved image: ./task1/women_clothing\page6_Kate_wool_jacket_3.jpg
# Saved image: ./task1/women_clothing\page6_Dawning_linen_and_silk_midi_dress_4.jpg
# Saved image: ./task1/women_clothing\page6_Silk_satin_slip_dress_5.jpg
# Saved image: ./task1/women_clothing\page6_Jersey_top_6.jpg
# Saved image: ./task1/women_clothing\page6_Bing_Court_cotton-blend_slim_pants_7.jpg
# Saved image: ./task1/women_clothing\page6_Ruffled_virgin_wool_sweater_8.jpg
# Saved image: ./task1/women_clothing\page6_Scarf-detail_silk_blouse_9.jpg
# Saved image: ./task1/women_clothing\page6_Pompeo_cotton-blend_jersey_sweatpants_10.jpg
# Saved image: ./task1/women_clothing\page6_Maya_70_down_jacket_11.jpg
# Saved image: ./task1/women_clothing\page6_Amati_cropped_faux_leather_wide-leg_pants_12.jpg
# Saved image: ./task1/women_clothing\page6_Ascension_shirred_floral_blouse_13.jpg
# Saved image: ./task1/women_clothing\page6_Ruffled_virgin_wool_sweater_14.jpg
# Saved image: ./task1/women_clothing\page6_Estate_suede_overshirt_15.jpg
# Saved image: ./task1/women_clothing\page6_Cotton_shirt_16.jpg
# Saved image: ./task1/women_clothing\page6_Ornella_belted_virgin_wool_coat_17.jpg
# Saved image: ./task1/women_clothing\page6_Cutout_leopard-print_swimsuit_18.jpg
# Saved image: ./task1/women_clothing\page6_New_Sahal_silk_straight_pants_19.jpg
# Saved image: ./task1/women_clothing\page6_Ascension_floral_linen_minidress_20.jpg
# Saved image: ./task1/women_clothing\page6_Cashmere_sweater_21.jpg
# Saved image: ./task1/women_clothing\page6_Brando_high-rise_suede_wide-leg_pants_22.jpg
# Saved image: ./task1/women_clothing\page6_Cedro_wool_and_cashmere_cardigan_23.jpg
# Saved image: ./task1/women_clothing\page6_Lokai_cotton_canvas_jacket_24.jpg
# Saved image: ./task1/women_clothing\page6_Kate_scarf-detail_virgin_wool_jacket_25.jpg
# Saved image: ./task1/women_clothing\page6_Ruffled_virgin_wool_sweater_26.jpg
# Saved image: ./task1/women_clothing\page6_Cochevis_down_jacket_27.jpg
# Saved image: ./task1/women_clothing\page6_Cantone_wool_turtleneck_top_28.jpg
# Saved image: ./task1/women_clothing\page6_Cashmere_top_29.jpg
# Saved image: ./task1/women_clothing\page6_Agneux_belted_quilted_down_jacket_30.jpg
# Saved image: ./task1/women_clothing\page6_Tori_cotton_jersey_T-shirt_31.jpg
# Saved image: ./task1/women_clothing\page6_Satin_wrap_dress_32.jpg
# Saved image: ./task1/women_clothing\page6_Cantone_wool_turtleneck_top_33.jpg
# Saved image: ./task1/women_clothing\page6_Ruffled_minidress_34.jpg
# Saved image: ./task1/women_clothing\page6_Cascadian_floral_ramie_blouse_35.jpg
# Saved image: ./task1/women_clothing\page6_Kiso_suede_jacket_36.jpg
# Saved image: ./task1/women_clothing\page6_Enzo_virgin_wool_wrap_coat_37.jpg
# Saved image: ./task1/women_clothing\page6_Crepe_Couture_bow-detail_minidress_38.jpg
# Saved image: ./task1/women_clothing\page6_Ruffled_silk_crêpe_de_chine_blouse_39.jpg
# Saved image: ./task1/women_clothing\page6_Belted_lace_minidress_40.jpg
# Saved image: ./task1/women_clothing\page6_Avoce_down_jacket__41.jpg
# Saved image: ./task1/women_clothing\page6_Bow-detail_cable-knit_virgin_wool_sweater_42.jpg
# Saved image: ./task1/women_clothing\page6_Costanza_virgin_wool_jacket_43.jpg
# Saved image: ./task1/women_clothing\page6_Everynight_double-breasted_cotton_velvet_blazer_44.jpg
# Saved image: ./task1/women_clothing\page6_Printed_cotton_beach_cover-up_45.jpg
# Saved image: ./task1/women_clothing\page6_Tahiti_straight_pants_46.jpg
# Saved image: ./task1/women_clothing\page6_Leather_midi_skirt_47.jpg
# Saved image: ./task1/women_clothing\page6_Cotton_gabardine_shorts_48.jpg
# Saved image: ./task1/women_clothing\page6_Rhiannon_ruffled_linen_midi_dress_49.jpg
# Saved image: ./task1/women_clothing\page6_Quilted_midi_skirt_50.jpg
# Saved image: ./task1/women_clothing\page6_Asymmetric_draped_maxi_dress_51.jpg
# Saved image: ./task1/women_clothing\page6_Sweet_Winter_virgin_wool_sweater_52.jpg
# Saved image: ./task1/women_clothing\page6_Cashmere_sweatpants_53.jpg
# Saved image: ./task1/women_clothing\page6_Tafira_cotton-blend_flared_pants_54.jpg
# Saved image: ./task1/women_clothing\page6_Cashmere_cardigan_55.jpg
# Saved image: ./task1/women_clothing\page6_Floral_pencil_skirt_56.jpg
# Saved image: ./task1/women_clothing\page6_Gathered_jersey_gown_57.jpg
# Saved image: ./task1/women_clothing\page6_Lace-trimmed_semi-sheer_silk_top_58.jpg
# Saved image: ./task1/women_clothing\page6_Silk_satin_slip_dress_59.jpg
# Saved image: ./task1/women_clothing\page6_Metallic-effect_lace_midi_skirt_60.jpg
# Requesting page 7 ...
# Found 60 products on page 7
# Saved image: ./task1/women_clothing\page7_Printed_midi_skirt_1.jpg
# Saved image: ./task1/women_clothing\page7_Printed_linen_jumpsuit_2.jpg
# Saved image: ./task1/women_clothing\page7_Virgin_wool_pencil_skirt_3.jpg
# Saved image: ./task1/women_clothing\page7_Brunate_paneled_midi_skirt_4.jpg
# Saved image: ./task1/women_clothing\page7_Balia_striped_wool_sweater_5.jpg
# Saved image: ./task1/women_clothing\page7_Lucky_floral_linen_minidress_6.jpg
# Saved image: ./task1/women_clothing\page7_Gathered_printed_midi_dress_7.jpg
# Saved image: ./task1/women_clothing\page7_Ruffled_wool-blend_miniskirt_8.jpg
# Saved image: ./task1/women_clothing\page7_Oversized_striped_cotton_poplin_shirt_9.jpg
# Saved image: ./task1/women_clothing\page7_Single-breasted_blazer_10.jpg
# Saved image: ./task1/women_clothing\page7_Crêpe_satin_gown_11.jpg
# Saved image: ./task1/women_clothing\page7_Floral_semi-sheer_cotton_minidress_12.jpg
# Saved image: ./task1/women_clothing\page7_Cashmere_turtleneck_midi_dress_13.jpg
# Saved image: ./task1/women_clothing\page7_Maire_down_jacket_14.jpg
# Saved image: ./task1/women_clothing\page7_Cotton_midi_dress_15.jpg
# Saved image: ./task1/women_clothing\page7_Scarf-detail_printed_silk_blouse_16.jpg
# Saved image: ./task1/women_clothing\page7_Metallic-effect_lace_maxi_dress_17.jpg
# Saved image: ./task1/women_clothing\page7_Leather_midi_skirt_18.jpg
# Saved image: ./task1/women_clothing\page7_Printed_bikini_bottoms_19.jpg
# Saved image: ./task1/women_clothing\page7_Underwater_Barocco_bikini_top_20.jpg
# Saved image: ./task1/women_clothing\page7_Logo_cotton_jersey_T-shirt_21.jpg
# Saved image: ./task1/women_clothing\page7_Logo_jersey_leggings_22.jpg
# Saved image: ./task1/women_clothing\page7_Majolica_cotton-blend_minidress_23.jpg
# Saved image: ./task1/women_clothing\page7_Aloe_cotton-blend_maxi_skirt_24.jpg
# Saved image: ./task1/women_clothing\page7_Anagram_cotton_piqué_polo_shirt_25.jpg
# Saved image: ./task1/women_clothing\page7_Roseto_alpaca_and_wool_coat_26.jpg
# Saved image: ./task1/women_clothing\page7_Cashair_cashmere_cardigan_27.jpg
# Saved image: ./task1/women_clothing\page7_Asymmetric_midi_dress_28.jpg
# Saved image: ./task1/women_clothing\page7_Cascadian_crochet_keyhole_cutout_swimsuit_29.jpg
# Saved image: ./task1/women_clothing\page7_Claudia_printed_ruched_jersey_shirt_dress_30.jpg
# Saved image: ./task1/women_clothing\page7_Ascension_beaded_floral_linen_shorts_31.jpg
# Saved image: ./task1/women_clothing\page7_Embellished_jersey_sweatshirt_32.jpg
# Saved image: ./task1/women_clothing\page7_Embellished_jersey_sweatshirt_33.jpg
# Saved image: ./task1/women_clothing\page7_Brunate_paneled_midi_skirt_34.jpg
# Saved image: ./task1/women_clothing\page7_Ade_plissé_crêpe_midi_skirt_35.jpg
# Saved image: ./task1/women_clothing\page7_Printed_cotton_beach_cover-up_36.jpg
# Saved image: ./task1/women_clothing\page7_Isaak_silk_satin_maxi_skirt_37.jpg
# Saved image: ./task1/women_clothing\page7_Seraphim_wool-blend_straight_pants_38.jpg
# Saved image: ./task1/women_clothing\page7_Burberry_Check_cropped_cotton_shirt_39.jpg
# Saved image: ./task1/women_clothing\page7_Hypnotic_high-rise_wide-leg_jeans_40.jpg
# Saved image: ./task1/women_clothing\page7_Printed_high-rise_silk_straight_pants_41.jpg
# Saved image: ./task1/women_clothing\page7_Cassini_wool_and_cotton_blazer_42.jpg
# Saved image: ./task1/women_clothing\page7_Lila_knitted_cashmere_top_43.jpg
# Saved image: ./task1/women_clothing\page7_Cassia_wool_wrap_coat_44.jpg
# Saved image: ./task1/women_clothing\page7_Paul_double-breasted_virgin_wool_coat_45.jpg
# Saved image: ./task1/women_clothing\page7_Striped_cotton_and_silk_polo_shirt_46.jpg
# Saved image: ./task1/women_clothing\page7_Checked_wool_and_cashmere_miniskirt_47.jpg
# Saved image: ./task1/women_clothing\page7_New_Sahel_silk_straight_pants_48.jpg
# Saved image: ./task1/women_clothing\page7_Majolica_silk-blend_culottes_49.jpg
# Saved image: ./task1/women_clothing\page7_Crepe_Couture_ruffled_midi_dress_50.jpg
# Saved image: ./task1/women_clothing\page7_Levi_cashmere_sweater_vest_51.jpg
# Saved image: ./task1/women_clothing\page7_Lucky_floral_linen_minidress_52.jpg
# Saved image: ./task1/women_clothing\page7_Printed_cotton_beach_cover-up_53.jpg
# Saved image: ./task1/women_clothing\page7_Costanza_virgin_wool_jacket_54.jpg
# Saved image: ./task1/women_clothing\page7_Hulin_silk-blend_wide-leg_pants_55.jpg
# Saved image: ./task1/women_clothing\page7_Coci_cotton_velvet_miniskirt_56.jpg
# Saved image: ./task1/women_clothing\page7_Ribbed-knit_logo_cotton-blend_bodysuit_57.jpg
# Saved image: ./task1/women_clothing\page7_Rhiannon_crochet_cotton_tank_top_58.jpg
# Saved image: ./task1/women_clothing\page7_Crepe_Couture_midi_dress_59.jpg
# Saved image: ./task1/women_clothing\page7_Shearling_jacket_60.jpg
# Requesting page 8 ...
# Found 60 products on page 8
# Saved image: ./task1/women_clothing\page8_Iverness_knitted_cashmere_top_1.jpg
# Saved image: ./task1/women_clothing\page8_Mirla_jersey_maxi_skirt_2.jpg
# Saved image: ./task1/women_clothing\page8_Leather_midi_skirt_3.jpg
# Saved image: ./task1/women_clothing\page8_Athena_striped_silk-blend_shirt_4.jpg
# Saved image: ./task1/women_clothing\page8_Louison_striped_silk-blend_top_5.jpg
# Saved image: ./task1/women_clothing\page8_Striped_cotton_and_silk_maxi_skirt_6.jpg
# Saved image: ./task1/women_clothing\page8_Leonie_ruched_midi_skirt_7.jpg
# Saved image: ./task1/women_clothing\page8_Down-paneled_virgin_wool_cardigan_8.jpg
# Saved image: ./task1/women_clothing\page8_Down-paneled_virgin_wool_cardigan_9.jpg
# Saved image: ./task1/women_clothing\page8_Cotton_jersey_T-shirt_10.jpg
# Saved image: ./task1/women_clothing\page8_Cotton_shirt_dress_11.jpg
# Saved image: ./task1/women_clothing\page8_Volta_belted_plissé_satin_midi_dress_12.jpg
# Saved image: ./task1/women_clothing\page8_Satie_jacket_13.jpg
# Saved image: ./task1/women_clothing\page8_Mid-rise_skinny_jeans_14.jpg
# Saved image: ./task1/women_clothing\page8_Mid-rise_skinny_jeans_15.jpg
# Saved image: ./task1/women_clothing\page8_Crepe_Couture_bow-detail_minidress_16.jpg
# Saved image: ./task1/women_clothing\page8_Belted_halterneck_swimsuit_17.jpg
# Saved image: ./task1/women_clothing\page8_Gathered_minidress_18.jpg
# Saved image: ./task1/women_clothing\page8_Dawning_linen_and_silk_midi_dress_19.jpg
# Saved image: ./task1/women_clothing\page8_Hulin_silk-blend_wide-leg_pants_20.jpg
# Saved image: ./task1/women_clothing\page8_Lena_wool_blazer_21.jpg
# Saved image: ./task1/women_clothing\page8_Rollet_wool_and_silk_coat_22.jpg
# Saved image: ./task1/women_clothing\page8_High-rise_wool_midi_skirt_23.jpg
# Saved image: ./task1/women_clothing\page8_Clea_silk_satin_camisole_24.jpg
# Saved image: ./task1/women_clothing\page8_Printed_wide-leg_pants_25.jpg
# Saved image: ./task1/women_clothing\page8_Printed_linen_tunic_26.jpg
# Saved image: ./task1/women_clothing\page8_Hypnotic_floral_silk_organza_blouse_27.jpg
# Saved image: ./task1/women_clothing\page8_Tiered_cotton-blend_midi_skirt_28.jpg
# Saved image: ./task1/women_clothing\page8_Burberry_Check_cotton_shorts_29.jpg
# Saved image: ./task1/women_clothing\page8_Hypnotic_floral_silk_organza_maxi_skirt_30.jpg
# Saved image: ./task1/women_clothing\page8_Cardigan_31.jpg
# Saved image: ./task1/women_clothing\page8_Isaak_silk_maxi_skirt_32.jpg
# Saved image: ./task1/women_clothing\page8_Coleman_suede_slim_pants_33.jpg
# Saved image: ./task1/women_clothing\page8_Duke_leather_slim_pants_34.jpg
# Saved image: ./task1/women_clothing\page8_Cascadian_floral_linen_shorts_35.jpg
# Saved image: ./task1/women_clothing\page8_Wool_and_cashmere_jacket_36.jpg
# Saved image: ./task1/women_clothing\page8_Chain-detail_printed_bikini_37.jpg
# Saved image: ./task1/women_clothing\page8_Belted_quilted_down_jacket_38.jpg
# Saved image: ./task1/women_clothing\page8_Cecie_Fair_Isle_wool-blend_sweater_39.jpg
# Saved image: ./task1/women_clothing\page8_Cammie_Fair_Isle_wool-blend_cardigan_40.jpg
# Saved image: ./task1/women_clothing\page8_High-rise_pointelle_shorts_41.jpg
# Saved image: ./task1/women_clothing\page8_Anagram_cable-knit_cotton_cardigan_42.jpg
# Saved image: ./task1/women_clothing\page8_Mossi_bow-detail_cotton_top_43.jpg
# Saved image: ./task1/women_clothing\page8_Feather-trimmed_virgin_wool_cardigan_44.jpg
# Saved image: ./task1/women_clothing\page8_Crepe_Couture_ruffled_minidress_45.jpg
# Saved image: ./task1/women_clothing\page8_Striped_wide-leg_pants_46.jpg
# Saved image: ./task1/women_clothing\page8_Polka-dot_silk_twill_minidress_47.jpg
# Saved image: ./task1/women_clothing\page8_Wool_and_cashmere_sweater_48.jpg
# Saved image: ./task1/women_clothing\page8_Cotton_maxi_dress_49.jpg
# Saved image: ./task1/women_clothing\page8_Lokai_wool_and_silk-blend_jacket_50.jpg
# Saved image: ./task1/women_clothing\page8_Rhiannon_gathered_corset_dress_51.jpg
# Saved image: ./task1/women_clothing\page8_Cutout_striped_swimsuit_52.jpg
# Saved image: ./task1/women_clothing\page8_Ribbed-knit_cotton_tank_top_53.jpg
# Saved image: ./task1/women_clothing\page8_Reversible_wool_and_cashmere_coat_54.jpg
# Saved image: ./task1/women_clothing\page8_Quilted_down_jacket__55.jpg
# Saved image: ./task1/women_clothing\page8_Paso_embroidered_straight_jeans_56.jpg
# Saved image: ./task1/women_clothing\page8_Belted_wrap_dress_57.jpg
# Saved image: ./task1/women_clothing\page8_Ruffled_silk_crêpe_minidress_58.jpg
# Saved image: ./task1/women_clothing\page8_Cashmere_sweater_59.jpg
# Saved image: ./task1/women_clothing\page8_Rhiannon_crochet_cotton_shorts_60.jpg
# Requesting page 9 ...
# Found 60 products on page 9
# Saved image: ./task1/women_clothing\page9_Satin_minidress_1.jpg
# Saved image: ./task1/women_clothing\page9_Leopard-print_silk_satin_maxi_dress_2.jpg
# Saved image: ./task1/women_clothing\page9_Cascadian_crochet_floral_bikini_3.jpg
# Saved image: ./task1/women_clothing\page9_Egidio_virgin_wool_top_4.jpg
# Saved image: ./task1/women_clothing\page9_Leather_single-breasted_blazer_5.jpg
# Saved image: ./task1/women_clothing\page9_Frilled_swimsuit_6.jpg
# Saved image: ./task1/women_clothing\page9_Nana_cotton_velvet_straight_pants_7.jpg
# Saved image: ./task1/women_clothing\page9_Silk_tank_top_8.jpg
# Saved image: ./task1/women_clothing\page9_Wide-leg_pants_9.jpg
# Saved image: ./task1/women_clothing\page9_Striped_shirt_10.jpg
# Saved image: ./task1/women_clothing\page9_Macramé_midi_dress_11.jpg
# Saved image: ./task1/women_clothing\page9_High-rise_barrel-leg_jeans_12.jpg
# Saved image: ./task1/women_clothing\page9_Arline_wool_and_cashmere_coat_13.jpg
# Saved image: ./task1/women_clothing\page9_Wool_sweater_14.jpg
# Saved image: ./task1/women_clothing\page9_Anagram_barrel-leg_jeans_15.jpg
# Saved image: ./task1/women_clothing\page9_Knitted_top_16.jpg
# Saved image: ./task1/women_clothing\page9_Gliss_reversible_shearling_jacket_17.jpg
# Saved image: ./task1/women_clothing\page9_Wool_and_cashmere-blend_jacket_18.jpg
# Saved image: ./task1/women_clothing\page9_Glimpse_Of_Eden_cardigan_19.jpg
# Saved image: ./task1/women_clothing\page9_Palm_Grove_Tales_cardigan__20.jpg

# %%
# This code scrapes 50 saint-laurent design images in 1024*1024 resolution

import os
import requests
import time
import re

url = "https://api.mytheresa.com/api"

headers = {
    "accept": "*/*",
    "accept-language": "en",
    "content-type": "text/plain;charset=UTF-8",
    "origin": "https://www.mytheresa.com",
    "priority": "u=1, i",
    "referer": "https://www.mytheresa.com/",
    "sec-ch-ua": '"Not;A=Brand";v="99", "Microsoft Edge";v="139", "Chromium";v="139"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-site",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36 Edg/139.0.0.0",
    "x-country": "GB",
    "x-region": "BY",
    "x-section": "women",
    "x-store": "GB",
}

cookies = {
    "mt_consent": "4",
}

json_query = """query XProductListingPageQuery($categories: [String], $colors: [String], $designers: [String], $fta: Boolean, $materials: [String], $page: Int, $patterns: [String], $reductionRange: [String], $saleStatus: SaleStatusEnum, $size: Int, $sizesHarmonized: [String], $slug: String, $sort: String) {
  xProductListingPage(categories: $categories, colors: $colors, designers: $designers, fta: $fta, materials: $materials, page: $page, patterns: $patterns, reductionRange: $reductionRange, saleStatus: $saleStatus, size: $size, sizesHarmonized: $sizesHarmonized, slug: $slug, sort: $sort) {
    products {
      name
      displayImages
    }
  }
}"""

save_dir = "./women_saint_laurent"
os.makedirs(save_dir, exist_ok=True)

def force_1024_image_url(url):
    # Replace segments like /1088/1088/ or /720/720/ with /1024/1024/
    return re.sub(r'/\d{3,4}/\d{3,4}/', '/1024/1024/', url)

def download_images_from_saint_laurent(max_images=50):
    variables = {
        "categories": [],
        "colors": [],
        "designers": ["Saint Laurent"],  # Designer filter
        "fta": None,
        "materials": [],
        "page": 1,
        "patterns": [],
        "reductionRange": [],
        "saleStatus": None,
        "size": max_images,  # request up to max_images products
        "sizesHarmonized": [],
        "slug": "/designers/saint-laurent",
        "sort": None,
    }

    json_data = {
        "query": json_query,
        "variables": variables,
    }

    print("Requesting Saint Laurent women designer page, page 1...")
    response = requests.post(url, headers=headers, cookies=cookies, json=json_data)
    if response.status_code != 200:
        print(f"Failed to fetch data: status {response.status_code}")
        return

    data = response.json()
    products = data.get('data', {}).get('xProductListingPage', {}).get('products', [])
    print(f"Found {len(products)} products")

    count = 0
    for idx, product in enumerate(products, start=1):
        if count >= max_images:
            break
        images = product.get('displayImages', [])
        if not images:
            continue
        
        img_url = force_1024_image_url(images[1])  # Enforce 1024x1024 resolution

        try:
            img_response = requests.get(img_url)
            img_response.raise_for_status()
            ext = img_url.split('.')[-1].split('?')[0]
            safe_name = product.get('name', 'product').replace(' ', '_').replace('/', '_')
            filename = f"saint_laurent_{safe_name}_{idx}.{ext}"
            filepath = os.path.join(save_dir, filename)
            with open(filepath, 'wb') as f:
                f.write(img_response.content)
            print(f"Saved image: {filepath}")
            count += 1
            time.sleep(0.1)
        except Exception as e:
            print(f"Failed to download image {img_url}: {e}")

download_images_from_saint_laurent(max_images=50)
# Out:
# Requesting Saint Laurent women designer page, page 1...
# Found 50 products
# Saved image: ./task1/women_saint_laurent\saint_laurent_Double-breasted_leather_bomber_jacket_1.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Leather_belt_2.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Cotton_velvet_pencil_skirt_3.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Nico_leather_platform_knee-high_boots_4.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Niki_Cassandre_suede_bucket_bag_5.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Suede_trench_coat_6.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Jill_95_leather_ankle_boots_7.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Ribbed-knit_maxi_dress_8.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Cashmere,_wool,_and_silk_sweater_9.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Puffer_Toy_leather_shoulder_bag_10.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Prince_of_Wales_wool_midi_skirt_11.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Le_Loafer_Cassandre_leather_penny_loafers_12.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Voltaire_Mini_leather_shoulder_bag_13.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Cropped_leather_jacket_14.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Herringbone_wool_wide-leg_pants_15.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Rossy_160_patent_leather_platform_sandals_16.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Wool,_cashmere,_and_silk_turtleneck_sweater_17.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Cassandre_leather_shoulder_bag_18.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Mid-rise_wool_culottes_19.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Vendome_50_leather_slingback_pump_20.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Wool_teddy_bomber_jacket_21.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Le_Loafer_leather_mules_22.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_High-rise_wide-leg_jeans_23.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Embellished_open-back_minidress_24.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_SL_557_Shade_oval_sunglasses_25.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Checked_pleated_silk_charmeuse_midi_dress_26.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Le_5_à_7_Large_leather_shoulder_bag_27.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Bubble_clip-on_earrings_28.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Saharienne_cotton_velvet_jacket_29.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Alain_leather_loafers_30.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Cotton_velvet_straight_pants_31.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Gaby_leather-trimmed_raffia_bucket_bag_32.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Floral-appliqué_embroidered_minidress_33.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Embellished_clip-on_earrings_34.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Nuit_110_crêpe_satin_sandals_35.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Checked_double-breasted_wool_blazer_36.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Leather_belt_37.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Chloé_90_leather_loafer_pumps_38.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Shopping_Large_leather_tote_bag_39.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Voltaire_Medium_leather_shoulder_bag_40.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Double-breasted_wool_coat_41.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Rainer_leather_ankle_boots_42.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Leather_belt_43.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Cotton_canvas_jacket_44.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Le_5_à_7_Supple_Large_suede_shoulder_bag_45.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Gym_leather_sneakers_46.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Jamie_4.3_Mini_shearling_shoulder_bag_47.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Double-breasted_silk_and_cashmere_blazer_48.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Leather_pencil_skirt_49.jpg
# Saved image: ./task1/women_saint_laurent\saint_laurent_Francoise_95_leather_knee-high_boots_50.jpg

# %%
# This code scrapes 100 shoes designs images in 1024*1024 resolution
import os
import requests
import time
import re

url = "https://api.mytheresa.com/api"

headers = {
    "accept": "*/*",
    "accept-language": "en",
    "content-type": "text/plain;charset=UTF-8",
    "origin": "https://www.mytheresa.com",
    "priority": "u=1, i",
    "referer": "https://www.mytheresa.com/",
    "sec-ch-ua": '"Not;A=Brand";v="99", "Microsoft Edge";v="139", "Chromium";v="139"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-site",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36 Edg/139.0.0.0",
    "x-country": "GB",
    "x-region": "BY",
    "x-section": "women",
    "x-store": "GB",
}

cookies = {
    "mt_consent": "4",
}

json_query = """query XProductListingPageQuery($categories: [String], $colors: [String], $designers: [String], $fta: Boolean, $materials: [String], $page: Int, $patterns: [String], $reductionRange: [String], $saleStatus: SaleStatusEnum, $size: Int, $sizesHarmonized: [String], $slug: String, $sort: String) {
  xProductListingPage(categories: $categories, colors: $colors, designers: $designers, fta: $fta, materials: $materials, page: $page, patterns: $patterns, reductionRange: $reductionRange, saleStatus: $saleStatus, size: $size, sizesHarmonized: $sizesHarmonized, slug: $slug, sort: $sort) {
    products {
      name
      displayImages
    }
  }
}"""

save_dir = "./women_shoes"
os.makedirs(save_dir, exist_ok=True)

def force_1024_image_url(url):
    # Replace size segments like /1088/1088/ or /720/720/ with /1024/1024/
    return re.sub(r'/\d{3,4}/\d{3,4}/', '/1024/1024/', url)

def download_images_for_page(page, max_images):
    variables = {
        "categories": [],
        "colors": [],
        "designers": [],
        "fta": None,
        "materials": [],
        "page": page,
        "patterns": [],
        "reductionRange": [],
        "saleStatus": None,
        "size": max_images,
        "sizesHarmonized": [],
        "slug": "/shoes",
        "sort": None,
    }

    json_data = {
        "query": json_query,
        "variables": variables,
    }

    print(f"Requesting page {page}...")
    response = requests.post(url, headers=headers, cookies=cookies, json=json_data)
    if response.status_code != 200:
        print(f"Failed to fetch page {page}: status {response.status_code}")
        return

    data = response.json()
    products = data.get('data', {}).get('xProductListingPage', {}).get('products', [])
    print(f"Found {len(products)} products on page {page}")

    count = 0
    for idx, product in enumerate(products, start=1):
        if count >= max_images:
            break
        images = product.get('displayImages', [])
        if not images:
            continue
        
        img_url = force_1024_image_url(images[0])

        try:
            img_response = requests.get(img_url)
            img_response.raise_for_status()
            ext = img_url.split('.')[-1].split('?')[0]
            safe_name = product.get('name', 'product').replace(' ', '_').replace('/', '_')
            filename = f"page{page}_{safe_name}_{idx}.{ext}"
            filepath = os.path.join(save_dir, filename)
            with open(filepath, 'wb') as f:
                f.write(img_response.content)
            print(f"Saved image: {filepath}")
            count += 1
            time.sleep(0.1)
        except Exception as e:
            print(f"Failed to download image {img_url}: {e}")

# Download 60 images from page 1
download_images_for_page(1, 60)

# Download 40 images from page 2
download_images_for_page(2, 40)
# Out:
# Requesting page 1...
# Found 60 products on page 1
# Saved image: ./task1/women_shoes\page1_Horsebit_leather_ankle_boots_1.jpg
# Saved image: ./task1/women_shoes\page1_Horsebit_leather_ankle_boots_2.jpg
# Saved image: ./task1/women_shoes\page1_Soave_85_bow-detail_suede_mules_3.jpg
# Saved image: ./task1/women_shoes\page1_Soave_85_bow-detail_satin_sandals_4.jpg
# Saved image: ./task1/women_shoes\page1_Puffy_Heart_Ring_95_leather_mules_5.jpg
# Saved image: ./task1/women_shoes\page1_Puffy_Heart_Ring_95_suede_mules_6.jpg
# Saved image: ./task1/women_shoes\page1_Gommino_snake-effect_leather_driving_shoes_7.jpg
# Saved image: ./task1/women_shoes\page1_Gommino_snake-effect_leather_driving_shoes_8.jpg
# Saved image: ./task1/women_shoes\page1_Frann_35_metallic_leather_sandals__9.jpg
# Saved image: ./task1/women_shoes\page1_Frann_35_suede_sandals__10.jpg
# Saved image: ./task1/women_shoes\page1_La_Cruisette_embellished_espadrille_wedges_11.jpg
# Saved image: ./task1/women_shoes\page1_La_Cruisette_canvas_espadrille_wedges_12.jpg
# Saved image: ./task1/women_shoes\page1_Savoy_Horsebit_leather_loafer_pumps_13.jpg
# Saved image: ./task1/women_shoes\page1_Horsebit_leather_loafers_14.jpg
# Saved image: ./task1/women_shoes\page1_Endouce_velvet_Mary_Jane_flats_15.jpg
# Saved image: ./task1/women_shoes\page1_Endouce_floral_Mary_Jane_flats_16.jpg
# Saved image: ./task1/women_shoes\page1_Suede_sneakers_17.jpg
# Saved image: ./task1/women_shoes\page1_Leather-trimmed_suede_sneakers_18.jpg
# Saved image: ./task1/women_shoes\page1_Majolica_embellished_leather_sandals_19.jpg
# Saved image: ./task1/women_shoes\page1_Majolica_embellished_leather_sandals_20.jpg
# Saved image: ./task1/women_shoes\page1_GG_Horsebit_Erin_slingback_pumps_21.jpg
# Saved image: ./task1/women_shoes\page1_Horsebit_GG_velvet_mules_22.jpg
# Saved image: ./task1/women_shoes\page1_Alain_leather_loafers_23.jpg
# Saved image: ./task1/women_shoes\page1_Le_Loafer_Cassandre_leather_penny_loafers_24.jpg
# Saved image: ./task1/women_shoes\page1_Vivi_65_mesh_mules_25.jpg
# Saved image: ./task1/women_shoes\page1_Vivi_65_crystal-embellished_mesh_mules_26.jpg
# Saved image: ./task1/women_shoes\page1_95_leopard-print_suede_slingback_pumps_27.jpg
# Saved image: ./task1/women_shoes\page1_95_suede_pumps_28.jpg
# Saved image: ./task1/women_shoes\page1_Chloé_90_leather_loafer_pumps_29.jpg
# Saved image: ./task1/women_shoes\page1_Strappy_95_patent_leather_Mary_Jane_pumps_30.jpg
# Saved image: ./task1/women_shoes\page1_Sana_50_embellished_satin_mules_31.jpg
# Saved image: ./task1/women_shoes\page1_Scarlett_50_metallic_leather_mules_32.jpg
# Saved image: ./task1/women_shoes\page1_Lumiere_105_embellished_PVC_pumps_33.jpg
# Saved image: ./task1/women_shoes\page1_Stevie_100_crystal-embellished_satin_pumps_34.jpg
# Saved image: ./task1/women_shoes\page1_Marcy_embroidered_mesh_ballet_flats_35.jpg
# Saved image: ./task1/women_shoes\page1_Leather_ballet_flats_36.jpg
# Saved image: ./task1/women_shoes\page1_Britt_25_calf_hair_clogs_37.jpg
# Saved image: ./task1/women_shoes\page1_Britt_25_calf_hair_clogs_38.jpg
# Saved image: ./task1/women_shoes\page1_Bowow_75_leather_slingback_pumps_39.jpg
# Saved image: ./task1/women_shoes\page1_Bowow_75_leather_slingback_pumps_40.jpg
# Saved image: ./task1/women_shoes\page1_Black_Tie_105_bow-detail_satin_sandals_41.jpg
# Saved image: ./task1/women_shoes\page1_Black_Tie_105_mirrored_faux_leather_sandals_42.jpg
# Saved image: ./task1/women_shoes\page1_Floaty_fishnet_ballet_flats_43.jpg
# Saved image: ./task1/women_shoes\page1_Ruches_suede_Mary_Jane_flats_44.jpg
# Saved image: ./task1/women_shoes\page1_125_suede_platform_sandals_45.jpg
# Saved image: ./task1/women_shoes\page1_Organza_and_suede_platform_sandals_46.jpg
# Saved image: ./task1/women_shoes\page1_Cloudnova_X_running_shoes_47.jpg
# Saved image: ./task1/women_shoes\page1_Cloudtilt_running_shoes_48.jpg
# Saved image: ./task1/women_shoes\page1_Gommino_Macro_leather_driving_shoes_49.jpg
# Saved image: ./task1/women_shoes\page1_Gommino_fringed_leather_driving_shoes_50.jpg
# Saved image: ./task1/women_shoes\page1_Crochet_thong_sandals_51.jpg
# Saved image: ./task1/women_shoes\page1_Crochet_thong_sandals_52.jpg
# Saved image: ./task1/women_shoes\page1_60_leather_loafer_pumps_53.jpg
# Saved image: ./task1/women_shoes\page1_60_leather_loafer_pumps_54.jpg
# Saved image: ./task1/women_shoes\page1_Leather-trimmed_raffia_flats_55.jpg
# Saved image: ./task1/women_shoes\page1_Leather-trimmed_slingback_flats_56.jpg
# Saved image: ./task1/women_shoes\page1_Cloak_75_studded_leather_wedge_mules_57.jpg
# Saved image: ./task1/women_shoes\page1_Cloak_75_leather_peep-toe_wedge_mules_58.jpg
# Saved image: ./task1/women_shoes\page1_Super-Star_glitter_leather_sneakers_59.jpg
# Saved image: ./task1/women_shoes\page1_Ball_Star_suede_sneakers_60.jpg
# Requesting page 2...
# Found 40 products on page 2
# Saved image: ./task1/women_shoes\page2_Black_Tie_105_bow-detail_satin_sandals_1.jpg
# Saved image: ./task1/women_shoes\page2_Black_Tie_105_mirrored_faux_leather_sandals_2.jpg
# Saved image: ./task1/women_shoes\page2_Floaty_fishnet_ballet_flats_3.jpg
# Saved image: ./task1/women_shoes\page2_Ruches_suede_Mary_Jane_flats_4.jpg
# Saved image: ./task1/women_shoes\page2_125_suede_platform_sandals_5.jpg
# Saved image: ./task1/women_shoes\page2_Organza_and_suede_platform_sandals_6.jpg
# Saved image: ./task1/women_shoes\page2_Cloudnova_X_running_shoes_7.jpg
# Saved image: ./task1/women_shoes\page2_Cloudtilt_running_shoes_8.jpg
# Saved image: ./task1/women_shoes\page2_Gommino_Macro_leather_driving_shoes_9.jpg
# Saved image: ./task1/women_shoes\page2_Gommino_fringed_leather_driving_shoes_10.jpg
# Saved image: ./task1/women_shoes\page2_Crochet_thong_sandals_11.jpg
# Saved image: ./task1/women_shoes\page2_Crochet_thong_sandals_12.jpg
# Saved image: ./task1/women_shoes\page2_60_leather_loafer_pumps_13.jpg
# Saved image: ./task1/women_shoes\page2_60_leather_loafer_pumps_14.jpg
# Saved image: ./task1/women_shoes\page2_Leather-trimmed_raffia_flats_15.jpg
# Saved image: ./task1/women_shoes\page2_Leather-trimmed_slingback_flats_16.jpg
# Saved image: ./task1/women_shoes\page2_Cloak_75_studded_leather_wedge_mules_17.jpg
# Saved image: ./task1/women_shoes\page2_Cloak_75_leather_peep-toe_wedge_mules_18.jpg
# Saved image: ./task1/women_shoes\page2_Super-Star_glitter_leather_sneakers_19.jpg
# Saved image: ./task1/women_shoes\page2_Ball_Star_suede_sneakers_20.jpg
# Saved image: ./task1/women_shoes\page2_Liisa_35_pumps_21.jpg
# Saved image: ./task1/women_shoes\page2_Liisa_35_poplin_pumps_22.jpg
# Saved image: ./task1/women_shoes\page2_Leather_loafers_23.jpg
# Saved image: ./task1/women_shoes\page2_Leather_penny_loafers_24.jpg
# Saved image: ./task1/women_shoes\page2_Horsebit_leather_platform_mules_25.jpg
# Saved image: ./task1/women_shoes\page2_Horsebit_leather_platform_mules_26.jpg
# Saved image: ./task1/women_shoes\page2_VLogo_Signature_80_leather_platform_sandal_27.jpg
# Saved image: ./task1/women_shoes\page2_VLogo_Signature_80_leather_platform_sandals_28.jpg
# Saved image: ./task1/women_shoes\page2_Flower_Strass_65_embellished_satin_pumps_29.jpg
# Saved image: ./task1/women_shoes\page2_Viv'_In_The_City_65_slingback_pumps_30.jpg
# Saved image: ./task1/women_shoes\page2_Stella_leather_ballet_flats_31.jpg
# Saved image: ./task1/women_shoes\page2_Leather_Mary_Jane_ballet_flats_32.jpg
# Saved image: ./task1/women_shoes\page2_Double_G_leather_platform_sandals_33.jpg
# Saved image: ./task1/women_shoes\page2_Double_G_leather_platform_sandals_34.jpg
# Saved image: ./task1/women_shoes\page2_Bisous_85_embossed_leather_mules_35.jpg
# Saved image: ./task1/women_shoes\page2_Bisous_85_leopard-print_calf_hair_mules_36.jpg
# Saved image: ./task1/women_shoes\page2_Sculpted_95_mirrored_leather_mules_37.jpg
# Saved image: ./task1/women_shoes\page2_Sculpted_95_patent_leather_mules_38.jpg
# Saved image: ./task1/women_shoes\page2_Cleo_105_embellished_satin_sandals_39.jpg
# Saved image: ./task1/women_shoes\page2_Cleo_105_embellished_satin_sandals_40.jpg

# %%
# This code scrapes 20 gucci designs that are under 1000 euro images in 1024*1024 resolution
import os
import re
import requests
import json

url = "https://api.mytheresa.com/api"

headers = {
    "accept": "*/*",
    "accept-language": "en",
    "content-type": "text/plain;charset=UTF-8",
    "origin": "https://www.mytheresa.com",
    "priority": "u=1, i",
    "referer": "https://www.mytheresa.com/",
    "sec-ch-ua": '"Not;A=Brand";v="99", "Microsoft Edge";v="139", "Chromium";v="139"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-site",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36 Edg/139.0.0.0",
    "x-country": "GB",
    "x-region": "BY",
    "x-section": "women",
    "x-store": "GB",
}

cookies = {
    "mt_consent": "4",
}

query = """
query XProductListingPageQuery(
  $categories: [String], $colors: [String], $designers: [String], 
  $fta: Boolean, $materials: [String], $page: Int, $patterns: [String], 
  $reductionRange: [String], $saleStatus: SaleStatusEnum, $size: Int, 
  $sizesHarmonized: [String], $slug: String, $sort: String
) {
  xProductListingPage(
    categories: $categories, colors: $colors, designers: $designers, 
    fta: $fta, materials: $materials, page: $page, patterns: $patterns, 
    reductionRange: $reductionRange, saleStatus: $saleStatus, size: $size, 
    sizesHarmonized: $sizesHarmonized, slug: $slug, sort: $sort
  ) {
    products {
      name
      displayImages
      mainPrice
    }
  }
}
"""

def force_1024_image_url(url):
    # Replace any /width/height/ segment with /1024/1014/
    return re.sub(r'/\d{3,4}/\d{3,4}/', '/1024/1014/', url)

def download_image(url, save_path):
    try:
        resp = requests.get(url, stream=True)
        resp.raise_for_status()
        with open(save_path, "wb") as f:
            for chunk in resp.iter_content(1024):
                f.write(chunk)
        print(f"✅ Saved: {save_path}")
    except Exception as e:
        print(f"❌ Failed to download {url}: {e}")

save_dir = "./gucci_under_1000"
os.makedirs(save_dir, exist_ok=True)

total_saved = 0
max_images = 20

for page in range(1, 5):
    if total_saved >= max_images:
        break
    
    print(f"\n--- Scraping page {page} ---")
    variables = {
        "categories": [],
        "colors": [],
        "designers": ["Gucci"],
        "fta": None,
        "materials": [],
        "page": page,
        "patterns": [],
        "reductionRange": [],
        "saleStatus": None,
        "size": 20,
        "sizesHarmonized": [],
        "slug": "/designers/gucci",
        "sort": None,
    }

    resp = requests.post(url, headers=headers, cookies=cookies, json={
        "query": query,
        "variables": variables
    })
    
    data = resp.json()
    products = data.get("data", {}).get("xProductListingPage", {}).get("products", [])
    
    for product in products:
        if total_saved >= max_images:
            break
        
        price = product.get("mainPrice", 0) / 100  
        images = product.get("displayImages", [])
        name = product.get("name", "unknown_product")
        
        if price < 1000 and len(images) > 1:
            print(f"📌 {name} — ${price}")
            img_url = force_1024_image_url(images[0])  # Second image, forced resolution
            filename = f"page{page}_{name.replace(' ', '_')}.jpg"
            filepath = os.path.join(save_dir, filename)
            download_image(img_url, filepath)
            total_saved += 1

print(f"\n🎯 Finished — Total images saved: {total_saved}")
# Out:
# --- Scraping page 1 ---
# 📌 GG Canvas cotton-blend bootcut pants — $860.0
# ✅ Saved: ./task1/gucci_under_1000\page1_GG_Canvas_cotton-blend_bootcut_pants.jpg
# 📌 Double G leather platform sandals — $930.0
# ✅ Saved: ./task1/gucci_under_1000\page1_Double_G_leather_platform_sandals.jpg
# 📌 GG wool-blend jacquard scarf — $380.0
# ✅ Saved: ./task1/gucci_under_1000\page1_GG_wool-blend_jacquard_scarf.jpg
# 📌 Signoria velvet slingback pumps — $840.0
# ✅ Saved: ./task1/gucci_under_1000\page1_Signoria_velvet_slingback_pumps.jpg
# 📌 Dionysus patent leather belt — $380.0
# ✅ Saved: ./task1/gucci_under_1000\page1_Dionysus_patent_leather_belt.jpg
# 📌 Horsebit GG velvet platform sandals — $840.0
# ✅ Saved: ./task1/gucci_under_1000\page1_Horsebit_GG_velvet_platform_sandals.jpg
# 📌 Dionysus patent leather belt — $380.0
# ✅ Saved: ./task1/gucci_under_1000\page1_Dionysus_patent_leather_belt.jpg
# 📌 GG wool-blend jacquard scarf — $380.0
# ✅ Saved: ./task1/gucci_under_1000\page1_GG_wool-blend_jacquard_scarf.jpg
#
# --- Scraping page 2 ---
# 📌 Cashmere and silk top — $960.0
# ✅ Saved: ./task1/gucci_under_1000\page2_Cashmere_and_silk_top.jpg
# 📌 Gucci Flora silk twill scarf — $430.0
# ✅ Saved: ./task1/gucci_under_1000\page2_Gucci_Flora_silk_twill_scarf.jpg
# 📌 Horsebit Sylke suede boots — $875.0
# ✅ Saved: ./task1/gucci_under_1000\page2_Horsebit_Sylke_suede_boots.jpg
# 📌 Logo miniskirt — $640.0
# ✅ Saved: ./task1/gucci_under_1000\page2_Logo_miniskirt.jpg
# 📌 GG floral silk twill scarf — $430.0
# ✅ Saved: ./task1/gucci_under_1000\page2_GG_floral_silk_twill_scarf.jpg
# 📌 Horsebit Sylke suede boots — $875.0
# ✅ Saved: ./task1/gucci_under_1000\page2_Horsebit_Sylke_suede_boots.jpg
# 📌 Selene Horsebit patent leather sandals — $750.0
# ✅ Saved: ./task1/gucci_under_1000\page2_Selene_Horsebit_patent_leather_sandals.jpg
# 📌 Dionysus patent leather belt — $380.0
# ✅ Saved: ./task1/gucci_under_1000\page2_Dionysus_patent_leather_belt.jpg
# 📌 GG silk twill scarf — $175.0
# ✅ Saved: ./task1/gucci_under_1000\page2_GG_silk_twill_scarf.jpg
# 📌 Sylke Horsebit suede loafers — $840.0
# ✅ Saved: ./task1/gucci_under_1000\page2_Sylke_Horsebit_suede_loafers.jpg
#
# --- Scraping page 3 ---
# 📌 Lettering square sunglasses — $310.0
# ✅ Saved: ./task1/gucci_under_1000\page3_Lettering_square_sunglasses.jpg
# 📌 Cotton jersey T-shirt — $405.0
# ✅ Saved: ./task1/gucci_under_1000\page3_Cotton_jersey_T-shirt.jpg
#
# 🎯 Finished — Total images saved: 20
